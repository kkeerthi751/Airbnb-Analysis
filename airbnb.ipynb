# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymongo

# %%
client = pymongo.MongoClient('mongodb+srv://keerthivasan:apple123@cluster0.cz79j69.mongodb.net/')

db = client.sample_airbnb
collection = db.listingsAndReviews

# %%
data = []
for i in collection.find():
    data.append(i)

# %%
data[0]
# Out:
# {'_id': '1003530',
#  'listing_url': 'https://www.airbnb.com/rooms/1003530',
#  'name': 'New York City - Upper West Side Apt',
#  'summary': '',
#  'space': 'Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement.',
#  'description': "Murphy bed, optional second bedroom available. Wifi available, Hulu, Netflix, TV Eat-in kitchen. Bathroom with great shower/bath.  Washer/dryer in basement. New York City! Great neighborhood - many terrific restaurants, bakeries, bagelries. Within easy walking distance are restaurants with the cuisines from India, Thailand, Japan, China, Mexico, South America and Europe.  As well as the many small independent stores that line Broadway, there chain stores such as Urban Outfitters (clothing), Whole Foods (groceries), Sephora (cosmetics), Michaels (crafts), and Modell's (sporting goods). Equidistant to Central Park and Riverside Park which have walking/running/biking trails as well as tennis and racquet ball courts. 10-15 blocks from Columbia University between Broadway and Amsterdam. The International Hostel across the street is an airport shuttle bus and double-decker tour bus stop.  The Hostel also has services available to the neighborhood such as lectures, brochures, etc. Convenientl",
#  'neighborhood_overview': "Great neighborhood - many terrific restaurants, bakeries, bagelries. Within easy walking distance are restaurants with the cuisines from India, Thailand, Japan, China, Mexico, South America and Europe.  As well as the many small independent stores that line Broadway, there chain stores such as Urban Outfitters (clothing), Whole Foods (groceries), Sephora (cosmetics), Michaels (crafts), and Modell's (sporting goods). Equidistant to Central Park and Riverside Park which have walking/running/biking trails as well as tennis and racquet ball courts. 10-15 blocks from Columbia University between Broadway and Amsterdam. The International Hostel across the street is an airport shuttle bus and double-decker tour bus stop.  The Hostel also has services available to the neighborhood such as lectures, brochures, etc.",
#  'notes': 'My cat, Samantha, are in and out during the summer.  The apt is layed out in such a  way that each bedroom is very private.',
#  'transit': 'Conveniently located near 1, 2, 3, B & C subway lines. Also buses on Columbus Avenue (downtown), Amsterdam Avenue (uptown), and Broadway (uptown/downtown). Also near origination/termination of M60 bus which goes to/from LaGuardia Airport.',
#  'access': 'New York City!',
#  'interaction': '',
#  'house_rules': 'No smoking is permitted in the apartment. All towels that are used should be placed in the bath tub upon departure. I have a cat, Samantha, who can stay or go, whichever is preferred.   Please text me upon departure.',
#  'property_type': 'Apartment',
#  'room_type': 'Private room',
#  'bed_type': 'Real Bed',
#  'minimum_nights': '12',
#  'maximum_nights': '360',
#  'cancellation_policy': 'strict_14_with_grace_period',
#  'last_scraped': datetime.datetime(2019, 3, 7, 5, 0),
#  'calendar_last_scraped': datetime.datetime(2019, 3, 7, 5, 0),
#  'first_review': datetime.datetime(2013, 4, 29, 4, 0),
#  'last_review': datetime.datetime(2018, 8, 12, 4, 0),
#  'accommodates': 2,
#  'bedrooms': 1,
#  'beds': 1,
#  'number_of_reviews': 70,
#  'bathrooms': Decimal128('1.0'),
#  'amenities': ['Internet',
#   'Wifi',
#   'Air conditioning',
#   'Kitchen',
#   'Elevator',
#   'Buzzer/wireless intercom',
#   'Heating',
#   'Family/kid friendly',
#   'Washer',
#   'Dryer',
#   'translation missing: en.hosting_amenity_50'],
#  'price': Decimal128('135.00'),
#  'security_deposit': Decimal128('0.00'),
#  'cleaning_fee': Decimal128('135.00'),
#  'extra_people': Decimal128('0.00'),
#  'guests_included': Decimal128('1'),
#  'images': {'thumbnail_url': '',
#   'medium_url': '',
#   'picture_url': 'https://a0.muscache.com/im/pictures/15074036/a97119ed_original.jpg?aki_policy=large',
#   'xl_picture_url': ''},
#  'host': {'host_id': '454250',
#   'host_url': 'https://www.airbnb.com/users/show/454250',
#   'host_name': 'Greta',
#   'host_location': 'New York, New York, United States',
#   'host_about': 'By now I have lived longer in the city than the country however I feel equally at home in each. I like to keep one foot in each and help others to do the same!',
#   'host_response_time': 'within an hour',
#   'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': '',
#   'host_response_rate': 100,
#   'host_is_superhost': True,
#   'host_has_profile_pic': True,
#   'host_identity_verified': True,
#   'host_listings_count': 3,
#   'host_total_listings_count': 3,
#   'host_verifications': ['email',
#    'phone',
#    'reviews',
#    'jumio',
#    'offline_government_id',
#    'government_id']},
#  'address': {'street': 'New York, NY, United States',
#   'suburb': 'Manhattan',
#   'government_area': 'Upper West Side',
#   'market': 'New York',
#   'country': 'United States',
#   'country_code': 'US',
#   'location': {'type': 'Point',
#    'coordinates': [-73.96523, 40.79962],
#    'is_location_exact': False}},
#  'availability': {'availability_30': 0,
#   'availability_60': 0,
#   'availability_90': 0,
#   'availability_365': 93},
#  'review_scores': {'review_scores_accuracy': 10,
#   'review_scores_cleanliness': 9,
#   'review_scores_checkin': 10,
#   'review_scores_communication': 10,
#   'review_scores_location': 10,
#   'review_scores_value': 10,
#   'review_scores_rating': 94},
#  'reviews': [{'_id': '4351675',
#    'date': datetime.datetime(2013, 4, 29, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '3708459',
#    'reviewer_name': 'Josh',
#    'comments': "i had a really pleasant stay at greta's place. the location is super convenient -- and the area is fun, with lots of hidden gems. the apartment was comfortable and charming. greta was accommodating and hospitable and left some great cupcakes in the fridge. i give this place a strong endorsement."},
#   {'_id': '4848277',
#    'date': datetime.datetime(2013, 5, 28, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '4609491',
#    'reviewer_name': 'Ralf',
#    'comments': 'Greta has been a great host, and her apartment a great place to stay. Perfectly located for our adventures around NYC, it is a place full of character and, as I see it, a very authentic NY Apartment that makes you feel at home imediately. Great neighbourhood, great infrastructure around the apartment block. Very good for a perfect stay.'},
#   {'_id': '5094175',
#    'date': datetime.datetime(2013, 6, 11, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '6741662',
#    'reviewer_name': 'Mame',
#    'comments': "Greta was wonderful. We arrived late at night and she made sure we were able to get in. We also had to transfer to a hotel for work, and she allowed us to keep our belongings there until 3 so we wouldn't be carting our luggage until we needed to. The apartment was clean and large and in a wonderful neighborhood. She had lists and menus of places to eat. I couldn't have been happier with our arrangement. Thanks Greta!"},
#   {'_id': '5497796',
#    'date': datetime.datetime(2013, 7, 2, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '474156',
#    'reviewer_name': 'Lars',
#    'comments': "Greta's place is very well located, so close to the MTA 1 line, which takes you up and down Manhattan, which was perfect for me.  It was an easy 3 minute walk and be on your way to anywhere in NY. \r\nThe shower is something else, the best water pressure I have experienced in a long time.\r\nI thought the decor was cool and eclectic, Greta must have an artistic streak. The Murphy bed was comfortable, and the AC unit (not pictured) kept it nice and cool.  \r\nAlthough I didn't meet her, she arranged for a neighbor to meet me and show me in. He was cool and so were any other neighbors that I met. \r\nShe also left a list of suggestions where to shop and eat, along with menus which was helpful when I needed a late night meal. \r\nHighly recommended. \r\n"},
#   {'_id': '6933005',
#    'date': datetime.datetime(2013, 8, 31, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '6067127',
#    'reviewer_name': 'Nicole',
#    'comments': "I had a wonderful stay at Greta's NYC apartment. The apartment was clean and comfortable. She was a wonderful and informative host. I felt very welcomed in her home."},
#   {'_id': '7205029',
#    'date': datetime.datetime(2013, 9, 10, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '7743438',
#    'reviewer_name': 'Ute',
#    'comments': 'Hi Greta,\r\nyou have a wonderful place. We had a great time an felt really comfortable - little bit like beeing home in NY :)\r\nEverything worked out pretty good, also the connection to La Guardia Airport was perfect.\r\n\r\nThanks again :)\r\n'},
#   {'_id': '7464858',
#    'date': datetime.datetime(2013, 9, 21, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '8543724',
#    'reviewer_name': 'Drew',
#    'comments': 'Greta was very welcoming and helpful. Prompt email communication.\r\n\r\nA great stay for those in town to see Broadway shows, shopping or sight seeing the West Side. A few minutes walking and I was in Central Park.\r\n\r\nA definite recommendation.'},
#   {'_id': '7515354',
#    'date': datetime.datetime(2013, 9, 23, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '1683177',
#    'reviewer_name': 'Don',
#    'comments': 'Greta was flexible about our sign-in time, helpful as we arrived, and kind to return to us a bag that we left in her apartment.  The apartment is wonderfully located for transportation and things to do.  It is compact and comfy, full of interesting books and prints.  The bed is quite firm.'},
#   {'_id': '7871931',
#    'date': datetime.datetime(2013, 10, 7, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '2871729',
#    'reviewer_name': 'Heidi',
#    'comments': 'We spent three nights in Greta’s apartment. Her kitchen is fully-equipped and the sleeping arrangements are extremely comfortable. Greta is a very accommodating host and easy to communicate with. She was very gracious about our later-than-expected arrival and allowed us to stay in her apartment on our departure day until we left for an early evening flight. Her apartment is very well-located, with food markets, drug stores, restaurants and coffee shops within a block of her building. The building is ½ block from the #1 subway line, enabling easy access to all parts of Manhattan.'},
#   {'_id': '8136769',
#    'date': datetime.datetime(2013, 10, 17, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '7811780',
#    'reviewer_name': 'Julia',
#    'comments': "We enjoyed our stay in Greta's apartment very much. The location is perfect, near Central Park, Broadway and everything, and the apartment is extremely cosy. Greta was very welcoming and helpful. We had a great time and felt really comfortable. Thanks :-)\r\n"},
#   {'_id': '8210485',
#    'date': datetime.datetime(2013, 10, 21, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '8119019',
#    'reviewer_name': 'Diane',
#    'comments': "Our stay are Greta's was wonderful- she was so accomodating and welcoming.  Her apartment is lovely and such a great place to unwind from the hurried family weekend weekend we had.  Greta even accomodated the joining of my niece and nephew for one of the two nights with no problem.. Thank you so much, Greta, for your hospitality!  "},
#   {'_id': '8478870',
#    'date': datetime.datetime(2013, 11, 2, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '8140760',
#    'reviewer_name': 'Linda',
#    'comments': 'Greta was a gracious and accommodating host, even coming over during our stay to reset the wifi connections.  The location of the apartment is ideal, basically half a short block to the subway.  Her list of neighborhood restaurants was very helpful and we sampled as many as we were able to. She has everything organized well.'},
#   {'_id': '8587648',
#    'date': datetime.datetime(2013, 11, 6, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '9307997',
#    'reviewer_name': 'Maureen',
#    'comments': "Greta's apartment was comfortable and clean and the neighborhood was easily accessible to museums and other locations. A bit noisy at night."},
#   {'_id': '8768655',
#    'date': datetime.datetime(2013, 11, 17, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '9464736',
#    'reviewer_name': 'George',
#    'comments': 'Greta was extremely helpful throughout this process!  Communication was maintained throughout the process and throughout our stay.  She was able to answer any questions we had and even gave suggestions for us.  Her instructions were awesome and the information left at her apartment were great!  There was even a binder with additional information like places to eat and places to go.  She even took the time to make sure we knew how to use the radiator!  Being from Hawaii, we had no knowledge about radiators and how to use them - we really appreciated her thoughtfulness!'},
#   {'_id': '9179262',
#    'date': datetime.datetime(2013, 12, 11, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '9405167',
#    'reviewer_name': 'Whitney',
#    'comments': "Greta's apartment was homey, clean and just the right size for two (probably even three) people. Greta was extremely helpful in getting us settled and providing information about the neighborhood....etc. Murphy bed was very firm but comfortable. Great water pressure in shower. Apt is close to everything and  the neighborhood has so much to offer. I would definitely recommend Greta's place.  "},
#   {'_id': '9428838',
#    'date': datetime.datetime(2013, 12, 28, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '10297643',
#    'reviewer_name': 'Deborah & Tim',
#    'comments': "The apartment is very homey - it felt like I was staying in a friend's apartment. The bed is surprisingly comfy and firm (I have never slept in a Murphy bed before) and the shower had plenty of hot water and great pressure. Greta was very communicative and friendly, and was also incredibly accommodating when I had something come up unexpectedly and needed to stay a couple hours longer than I anticipated. Overall all it was a very cozy stay in a great location!"},
#   {'_id': '9543118',
#    'date': datetime.datetime(2014, 1, 2, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '8828184',
#    'reviewer_name': 'Catherine',
#    'comments': 'The location of this appartment was ideal! Just minutes away the subway and walking distance from Central Park, Riverside Park, and many good restaurants on Broadway. A quaint appartment, with a lot of cachet. I recommend it!!'},
#   {'_id': '20872115',
#    'date': datetime.datetime(2014, 10, 6, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '7838233',
#    'reviewer_name': 'Brandon',
#    'comments': 'What a delightful apartment!  I plan to stay here next time I bring family to New York. I would describe the apartment as a very warm, personal, comfortable and homey place to stay. It’s a corner apartment with good light, lots of books and  very good energy. Plus, the beds are quite comfortable. My daughter exclaimed “Hey Dad, come lie down in this one. You’ll never want to get up!”\r\n\r\nThe neighborhood was incredibly well located and enjoyable. The train stops  a half block away, and there are numerous excellent restaurants and conveniences close by. Greta, the host, provides a first-rate list of recommendations.\r\n\r\nGreta was a personable, helpful and extremely welcoming host. She was very quick to respond to my online inquiries and, once we arrived, to any further requests for advice.\r\n'},
#   {'_id': '22257920',
#    'date': datetime.datetime(2014, 11, 2, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '4034556',
#    'reviewer_name': 'Aparna',
#    'comments': 'Greta was a lovely host! She was communicative, helpful and flexible during the booking process and very responsive and friendly when we were at her place in NYC. The house is charming and comfortable, and very conveniently located right by the 1 train. We were two of us and only used one room, but the house can fit another person or two. \r\nFor anyone visiting NYC and looking to be in the city but not in the midst of the city noise, this is a great place to stay! You can be downtown in 20 minutes. '},
#   {'_id': '23415037',
#    'date': datetime.datetime(2014, 11, 30, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '22685675',
#    'reviewer_name': 'Karolina',
#    'comments': "I stayed at Greta's place for 3 days! It was a really pleasant stay! The bed was really comfortable. The place was clean and cozy. A minute from the subway station! I didnt meet Greta in person, but we were communicating all the time and she was really helpful and kind with everything I needed! I would love to stay again the next time! :) i surely recommend it! "},
#   {'_id': '23924172',
#    'date': datetime.datetime(2014, 12, 14, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '16534063',
#    'reviewer_name': 'Paul',
#    'comments': "Staying at Greta's apartment was delightful!  It's a wonderful, quirky New York apartment -- very compact, but also very comfy and accurately portrayed in the pictures.  The Murphy (fold-down) bed has a very thick memory foam mattress that is extremely comfortable.  Samantha (the cat) was a sweet little presence, but she kept mostly to herself so we barely saw her.  The location is great, less than a block to the 1 line, and there are several nice restaurants in the neighborhood.  Finally, Greta herself was a perfect host:  kind but not intrusive, thoughtful in her preparations for guests, and available should any problems arise (though none did).  A great airbnb experience!"},
#   {'_id': '28737168',
#    'date': datetime.datetime(2015, 3, 29, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '29115141',
#    'reviewer_name': 'Catherine',
#    'comments': 'Greta was a great host.  She met us late on Friday and explained everything about the apartment which we found very comfortable and fun.  I would highly recommend this apartment to anyone.  It is not luxurious but well-equipped and I loved the location, near Central Park and easy walk to museums.\r\n'},
#   {'_id': '29274122',
#    'date': datetime.datetime(2015, 4, 6, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '18417452',
#    'reviewer_name': 'Paul',
#    'comments': "Apt is beautifully as advertised, a comfortable place and beds, kitchen and bath. Arrival and departure were really well coordinated by host, the lovely Greta. Location is fabulously convenient on upper West side by subway, Amsterdam and Broadway restaurants, bars and history. We'd stay here again.  "},
#   {'_id': '29610000',
#    'date': datetime.datetime(2015, 4, 10, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '27919376',
#    'reviewer_name': 'Anika',
#    'comments': 'Greta was a lovely host, making sure we settled in well and could contact her easily if there were any problems. \r\nThe apartment is cosy with very comfortable beds and a well equipped kitchen in case you need a place to cook. It is also a nice neighborhood, with a lot of great places to eat nearby and it is a minute away from a subway station, so you are well connected to the rest of the city. We had a great time! '},
#   {'_id': '29775810',
#    'date': datetime.datetime(2015, 4, 12, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '20415509',
#    'reviewer_name': 'Jane',
#    'comments': 'My daughter and I stayed the weekend at Gretas place.  Greta was herself away for the weekend but everything was in great shape for us to stay and Greta was very available by phone for any questions.  Everything was very tidy and clean..comfy beds and good shower.  It was like home.  The location in the city is perfect..close to the park and subway.  I highly recommend Gretas home for aNew York stay!'},
#   {'_id': '30732097',
#    'date': datetime.datetime(2015, 4, 26, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '10570759',
#    'reviewer_name': 'Lakshmi',
#    'comments': "Greta is an amazing host and her apartment was super convenient for my stay in Manhattan. Here are my reasons:\r\nFirst - she as a person made me feel super welcome. I requested her a really early check in and she agreed (which was helpful because I took a red eye from Seattle). She also allowed me to keep my bags after my check out time so I could pick it up before my flight.\r\nSecond - her apartment location is SUPER convenient. Right next to the #1 and pretty close to B and C lines. NYC is all about location is this fits perfectly.\r\nThird - her apartment gives the feel of a typical NYC apartment. It is tiny but has everything you need. Two beds, a great shower, clean towels, and a kitchen (which I didn't use). Safe building with elevator. \r\n\r\nI would totally stay here again.  "},
#   {'_id': '31196460',
#    'date': datetime.datetime(2015, 5, 3, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '43102',
#    'reviewer_name': 'Catherine Et Albert',
#    'comments': "Greta was a fantastic host, we had a problem with a lost luggage at JFK and she helped us to coordinate the delivery. We also arrived later than scheduled in Manhattan, Greta was waiting for us, she welcomed us very friendly. The apartment is very nice and bright, the bed is very comfortable. Nice building with elevator, perfect location, between Riverside Park and Central Park, a block from the subway, lot of nice restaurants all around, we had a fantastic stay! Greta est une hôte fantastique, nous avons eu un problème de baggage à JFK et Greta nous a aidé à coordonner la livraison. Nous sommes arrivés plus tard que prévu et Greta nous a accueilli très chaleureseument. L'appartement est parfaitement situé, a un block du métro et entre Cantral Park et Riverside Park, il y a un ascenceur. Nombreux restaurants tout autour! Parfait nous recommandons vivement."},
#   {'_id': '31845940',
#    'date': datetime.datetime(2015, 5, 10, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '14717479',
#    'reviewer_name': 'Samantha',
#    'comments': 'We had a great stay with Greta.  She was a good communicator, flexible, and her apartment is a good value for the neighborhood.  We will definitely think about staying with her again.'},
#   {'_id': '33677946',
#    'date': datetime.datetime(2015, 5, 31, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '31114625',
#    'reviewer_name': 'Rebecca',
#    'comments': "My stay at Greta's place was perfect! The space is exactly as described, and was very clean and welcoming. Greta was very responsive to me, and even helped me figure out how to pick up the keys with my late arrival. Thank you!"},
#   {'_id': '36960183',
#    'date': datetime.datetime(2015, 7, 3, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '33119724',
#    'reviewer_name': 'Thomas',
#    'comments': 'Greta was an excellent hostess and was very accommodating. She took care of the little things that made a difference such as providing an extra set of keys and having the air conditioning on prior to my arrival. The apartment was clean and very comfortable. It instantly felt like "home". The location of the apartment was great! There are multiple grocery stores, restaurants, bars, etc. within a very short walking distance. The subway stop was very conveniently located as was Central Park and Riverside Park, which are both beautiful places for an afternoon walk. I would and have recommended this listing to friends that are traveling to the city and I would stay there again without hesitation. '},
#   {'_id': '37555310',
#    'date': datetime.datetime(2015, 7, 8, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '6352182',
#    'reviewer_name': 'Murray',
#    'comments': 'Greta is an excellent Airbnb host! She is warm, accommodating and very well organized. Her apt is located close to all amenities, Central and Riverside Parks, and bus/subway stops. The apt is clean, more spacious than expected, well stocked with anything you could possibly need, and has very comfortable beds and a first rate shower. I was travelling with my soon-to-be 17 year old daughter so she was thrilled to have her own bedroom! This is not fancy accommodation but warm and homey and probably a good representation of how an average New Yorker lives, although I suspect not many are as organized as Greta. Much recommended!'},
#   {'_id': '48783685',
#    'date': datetime.datetime(2015, 9, 28, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '43967256',
#    'reviewer_name': 'Judy',
#    'comments': "I have used airbnb in NYC several times, and this, by far, was my best experience.  The location is on a quiet street and on the same block as a major subway line.  You can't get any better than that.  The apartment has all the conveniences of a home - everything you'd need in a kitchen, extremely comfortable mattress, cable TV, air conditioning, wifi, great water pressure.  \r\n\r\nGreata goes way out of her way to make your stay as enjoyable as possible.  Her recommendations are outstanding and the check-in and check-out were  extremely easy.  This is a five star host and you won't go wrong with this choice for a stay in NYC. \r\n"},
#   {'_id': '53270568',
#    'date': datetime.datetime(2015, 11, 7, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '21960218',
#    'reviewer_name': 'Nicky',
#    'comments': "This is my second time staying at Greta's apartment. The best place to stay in NYC by far. There is a subway on the same street as the apartment, a two minute walk away (the 1 line) and multiple places to eat close by. There is also a CVS , Walgreens, grocery and liquor store within walking distance as well. The apartment is very clean and the bed is very comfortable. Checking in and out as easy as Greta is very flexible. The apartment is very spacious with a nice kitchen and lots of room in the fridge. I hope to continue to stay here every time I visit New York! "},
#   {'_id': '57574836',
#    'date': datetime.datetime(2015, 12, 27, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '50466815',
#    'reviewer_name': 'Obaseki',
#    'comments': 'Greta place is amazing and blissful. She was understand to our delayed scheduled. Her place is home away from home. Her details description gave us point of interest to visit. If I was to go to NYC again I would check Greta place available first.'},
#   {'_id': '58775965',
#    'date': datetime.datetime(2016, 1, 5, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '2692640',
#    'reviewer_name': 'Federica',
#    'comments': "We had a wonderful experience staying at Greta's flat. She is an amazing host: disposable, kind and always ready to answer back to our necessities, including late check-in and check-out. The flat itself is a true newyorker's one, warm, stylish and excellentlty connected with the subway. We strongly suggest it for everyone!"},
#   {'_id': '63209635',
#    'date': datetime.datetime(2016, 2, 21, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '4823592',
#    'reviewer_name': 'Lucinda',
#    'comments': "Greta was very welcoming and flexible.  My friend and I slept well in comfortable beds under soft cotton sheets in this lovely quiet flat on the upper west side.  We walked to the Museum of Natural History and hopped on the subway (less than one block away!) to go downtown.  Greta's place offered a sweet artful respite from the rush of the city."},
#   {'_id': '70519082',
#    'date': datetime.datetime(2016, 4, 18, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '59943151',
#    'reviewer_name': 'H',
#    'comments': "Greta was as amazing as her beautiful home!  The check in and check out process was easy.  Greta's communication was super convenient as she used text messaging and email to keep in constant communication.  Her apartment is beautifully decorated, extremely comfortable, and very welcoming.   The neighborhood is safe with stores and restaurants within a short walking distance.  I highly recommend Greta's apartment for renting.  You won't be disappointed."},
#   {'_id': '71843260',
#    'date': datetime.datetime(2016, 4, 29, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '31368654',
#    'reviewer_name': 'Peter',
#    'comments': 'What can we say? Greta is a delight and her place is perfect. The beds are comfortable, the kitchen is an eat-in and the bathroom is classic New York. The building is almost 150 years old and holds up. The location is perfect, a block to the 1 train and four blocks from the bus to LA Guardia. Everything was perfect and we already miss Samantha. Thank you Greta and we hope to be able to stay there in the future.'},
#   {'_id': '82291166',
#    'date': datetime.datetime(2016, 6, 27, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '4543077',
#    'reviewer_name': 'Stuart',
#    'comments': 'Easy to make arrangements, was readily available for questions, and flexible about arriving and departing. Highly recommend this Upper West Side accommodation.'},
#   {'_id': '84121201',
#    'date': datetime.datetime(2016, 7, 5, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '62507392',
#    'reviewer_name': 'Jean',
#    'comments': "Greta and I communicated regularly before my trip,she was prompt and helpful. She met me at the apartment and was very welcoming,filled me in on all I needed to know. The apartment is so lovely and convenient and cosy and beautiful! Great area. I'd love to come back."},
#   {'_id': '85258241',
#    'date': datetime.datetime(2016, 7, 10, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '42965012',
#    'reviewer_name': 'Gwen',
#    'comments': 'Greta went out of her way to assist us with difficult flight times and luggage which really made things easier for us. The area was good and as everyone notes, great for the subway, which works far better than the tourist buses which barely move at times with traffic. Lots of eateries etc handy. '},
#   {'_id': '86034388',
#    'date': datetime.datetime(2016, 7, 14, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '53587610',
#    'reviewer_name': 'Nesta',
#    'comments': "Throughout, all Greta's communications were prompt, friendly and helpful.  We felt very prepared and welcome in her apartment, which is charming, comfortable and well located - a real 'home-from-home' to return to after a hot day's sight-seeing.  It was fun to have a brief swap over with the previous visitors (agreed previously by email with Greta).   Many thanks for a great stay. "},
#   {'_id': '86519833',
#    'date': datetime.datetime(2016, 7, 16, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '576347',
#    'reviewer_name': 'Ifeoma',
#    'comments': 'This was a unique apartment in an excellent location. Great for anyone having business at Columbia University. Close to restaurants, transportation. Highly recommend. '},
#   {'_id': '88541809',
#    'date': datetime.datetime(2016, 7, 24, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '54217384',
#    'reviewer_name': 'Terri',
#    'comments': "Greta is a wonderful Host. Very honest, helpful. Great to work with. The neighborhood was awesome, close to subway, parks. Fabulous bagel store. The house is cute, quaint. Your really get the feel of what it's like to live there. I recommend this place. My daughter and I had a great time."},
#   {'_id': '89504780',
#    'date': datetime.datetime(2016, 7, 28, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '6273647',
#    'reviewer_name': 'Ralf',
#    'comments': 'short version: if available, take it! more details: Greta is a great host. very helpful and pragmatic about arrival and departure to accommodate travellers plans as best as possible. the apartment is very cosy and you feel like visiting a good friend or relative big apple. location between 2 subway lines and a 10min walk from central park is just great. a whole foods and other shops are on the way to get all necesseties. building is well maintained and clean like the whole neighborhood. surprisingly quite for the central location. we habe been there in july and were able to manage the heat well by the window aircons to have a good night sleep. Greta always replied immediately in the outmost helpful way during preparation and stay. thank you Greta! we will hopefully be back soon :)\n'},
#   {'_id': '90261939',
#    'date': datetime.datetime(2016, 7, 31, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '57249998',
#    'reviewer_name': 'Annesca',
#    'comments': 'Greta went through a lot of trouble to accommodate our flight times and make our arrival and departure as convenient as possible. Much appreciated!'},
#   {'_id': '92084727',
#    'date': datetime.datetime(2016, 8, 7, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '24815450',
#    'reviewer_name': 'Julien',
#    'comments': 'Nous avons apprécié la flexibilité de Greta pour répondre à nos questions et la localisation de l appartement très proche du métro.\r\n'},
#   {'_id': '94083156',
#    'date': datetime.datetime(2016, 8, 14, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '42965012',
#    'reviewer_name': 'Gwen',
#    'comments': "Our second stay at Greta's on the last leg of our holiday, the city was oh so hot and humid but fortunately her air conditioning was equal to the task. The subway entrance close to the apartment was manned and easy to buy and top up your pass, it is the only way to travel around the city. On leaving for the airport, after both our stays we had only to wait a minute on the corner with our luggage to get a taxi to the airport. Once again Greta allowed us to arrive and leave at times that suited us with our luggage which didn't leave us stranded for hours with difficult flight times from Australia which was a great relief, thanks so much Greta!"},
#   {'_id': '98202715',
#    'date': datetime.datetime(2016, 8, 29, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '20316967',
#    'reviewer_name': 'Jenny',
#    'comments': 'We had a wonderful stay in NYC. Greta was a wonderful host, excellent communication, very helpful and accommodating. The location was perfect for us near restaurants and Columbia. We would love to stay there again. Thank You Greta!'},
#   {'_id': '98674131',
#    'date': datetime.datetime(2016, 9, 1, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '54784830',
#    'reviewer_name': 'Terri',
#    'comments': 'The apartment is in a nice neighbor. The Italian restaurant next store was good. Communication with Greta was exceptional. We would definitely stay here again.'},
#   {'_id': '99485043',
#    'date': datetime.datetime(2016, 9, 5, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '59943151',
#    'reviewer_name': 'H',
#    'comments': "This was my second stay at Greta's place, and it was absolutely wonderful.  The apartment is clean, comfortable, and very well organized.  I especially love the decor and comfortable bedding. The neighborhood is safe and very convenient with easy access to bus lines and rail.  There is also a wide variety of restaurants within walking distance.  Greta is a very attentive and responsive hostess.  You will not be disappointed with her or her wonderful home.  I highly recommend!"},
#   {'_id': '101291814',
#    'date': datetime.datetime(2016, 9, 12, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '5919533',
#    'reviewer_name': 'Jean And Letitia',
#    'comments': "We had a great stay in New York City. Greta's apartment was perfect, great location just three blocks from Central Park and 1 block from major subway lines. The apartment was spacious, clean, quiet and welcoming. Thank you for making our new York experience even better. I greatly recommend Greta's place. She even let us stay until 2pm the day of departure. Thank you\r\nJean"},
#   {'_id': '106551953',
#    'date': datetime.datetime(2016, 10, 6, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '47795517',
#    'reviewer_name': 'Vicki',
#    'comments': "We thoroughly enjoyed our stay in New York. Greta's place was a home away from home. The location was ideal with subway station, shops and restaurants just a few minutes  walk, even an Italian restaurant next door.  Central Park only 2 blocks away. Greta is very obliging and helpful especially her flexibility with our late flights.  If we ever make it back to New York would definitely love to stay at Greta's again."},
#   {'_id': '117029086',
#    'date': datetime.datetime(2016, 12, 4, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '103606558',
#    'reviewer_name': 'Rachel And Jeff',
#    'comments': 'Great location close to subway & everything you would possibly need! Greta was very accommodating & if we stay in NYC again we will definitely be looking into booking her place first ;)'},
#   {'_id': '121690051',
#    'date': datetime.datetime(2016, 12, 18, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '205255',
#    'reviewer_name': 'Jill',
#    'comments': 'Great place for families! Nice location (we even found on-street parking easily), and great neighborhood for restaurants. '},
#   {'_id': '123299700',
#    'date': datetime.datetime(2016, 12, 28, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '97224933',
#    'reviewer_name': 'Sarah Michele',
#    'comments': 'Fantastic location and value. Host is very accommodating and responsive.'},
#   {'_id': '125121514',
#    'date': datetime.datetime(2017, 1, 4, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '23113137',
#    'reviewer_name': 'Kim',
#    'comments': 'Greta is an amazing host with a very cute apartment. She was very responsive to our questions and provided us with a lot of information about the area. The location was amazing, so close the the 1 and Starbucks, DD and grocery stores. Would 100% stay here again if I returned to New York. '},
#   {'_id': '144377714',
#    'date': datetime.datetime(2017, 4, 15, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '18142306',
#    'reviewer_name': 'Tracy',
#    'comments': "Greta's place is comfortable and homey.  Each of the three bedrooms has a door, which is a real treat in a big city! A true New York apartment experience!  Birds singing in the trees outside, comfy beds, loads of restaurants and grocery nearby. Lovely easy walks to Central Park, Riverside Park. Subway stop right on the corner. We took Lyft around due to my mom's use of a wheelchair in the streets. Drivers made good time to and from lower Manhattan via larger roads. Elevator made it easy to get to and from the 4th floor apartment, and being on the 4th floor removed us from the street a bit. "},
#   {'_id': '156378118',
#    'date': datetime.datetime(2017, 5, 30, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '120945155',
#    'reviewer_name': 'Adrian',
#    'comments': 'Overall a very nice apartment in a nice location. Plenty of restaurants in the area. Greta was a friendly and forthcoming host'},
#   {'_id': '158625916',
#    'date': datetime.datetime(2017, 6, 7, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '39779933',
#    'reviewer_name': 'Sandrina',
#    'comments': 'Great host, great Appartement, great location. Again any time. '},
#   {'_id': '166479697',
#    'date': datetime.datetime(2017, 7, 3, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '13818466',
#    'reviewer_name': 'Jeremy',
#    'comments': "The place was so conveniently located at a mere 1-2 minutes walk from the subway. It was very cozy, everything was neat and tidy and really made us feel like we were home. Greta went the extra mile to help us with the check-in, and was super fast and responsive and made sure we didn't lack anything! My go-to airbnb place of choice for the next time we'll be in town. "},
#   {'_id': '175167108',
#    'date': datetime.datetime(2017, 7, 28, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '22834501',
#    'reviewer_name': 'Kayla',
#    'comments': "Greta's place was perfect. We were in a three-week program at Columbia and walked into class each day. The place was spacious and quiet. Air conditioning was perfect in the hot New York summer! Would 100% stay again."},
#   {'_id': '177406415',
#    'date': datetime.datetime(2017, 8, 2, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '20960360',
#    'reviewer_name': 'Noel',
#    'comments': 'Lovely and homely apartment right in the heart of uptown Manhattan. Has a subway station on the same block, surrounded by great eats and just a couple of streets away from Central Park. Totally would come back when we visit New York again.'},
#   {'_id': '179377561',
#    'date': datetime.datetime(2017, 8, 7, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '91436256',
#    'reviewer_name': 'Rob',
#    'comments': "Greta's apartment is perfect for a couple who want to stay away from the noisy downtown area. The neighbourhood is peaceful, but has some good taverns and restaurants as well. Greta could not be any more helpful, going way beyond to get an item we left at the apartment to us. We cannot recommend Greta,s  highly enough."},
#   {'_id': '182396917',
#    'date': datetime.datetime(2017, 8, 14, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '45877006',
#    'reviewer_name': 'Joan',
#    'comments': 'It was lovely to have Greta to greet us. We thoroughly enjoyed our stay in New York and in her apartment.'},
#   {'_id': '187129145',
#    'date': datetime.datetime(2017, 8, 26, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '42556498',
#    'reviewer_name': 'Linda',
#    'comments': 'Gretas Appartement ist wirklich schön und gemütlich. Wir waren super zufrieden! Die Lage ist perfekt um zügig in Richtung Downtown oder in den Central Park zu gelangen. Falls man mit dem Auto anreist ist das Parken auf der Straße kostenlos. Auch Check-In und Kommunikation liefen völlig reibungslos. Sehr zu empfehlen!'},
#   {'_id': '201967739',
#    'date': datetime.datetime(2017, 10, 9, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '13818466',
#    'reviewer_name': 'Jeremy',
#    'comments': "This was our 2nd stay at Greta's place and we loved it just as much as the first time we stayed. Again, great location (1 min walk from the subway), and we even managed to find free parking around! The place is really cozy and it's starting to feel like our 2nd home in NYC. Good shower, kitchen, separate bedrooms and a nice neighborhood close to central park. What more can you need? Highly recommended!"},
#   {'_id': '223508188',
#    'date': datetime.datetime(2018, 1, 1, 5, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '14723761',
#    'reviewer_name': 'Bruna',
#    'comments': 'We had a really great time at Greta’s apartment! First of all she was very nice with us since the beggining, helping with all our doubts. The apartment is near of Central Park and a lot of stores and restaurants. It’s a calm local neighborhood, to live your days in the city like a real new yorker :) . The place was very clean, the shower was good and beds was confortable. The heater sistem worked very well and kept us warm always - it was very important, because the temperatures was very low during our stay there. We definetelly recomend this place to stay! '},
#   {'_id': '245763661',
#    'date': datetime.datetime(2018, 3, 23, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '60691725',
#    'reviewer_name': 'Andrea',
#    'comments': 'Loved the stay here. Greta is a wonderful host. The room is spacious and you have everything you need. The neighborhood is beautiful, lots of restaurants nearby, and the red train is literally next to the apartment. \nDefinitely recommended.'},
#   {'_id': '306501176',
#    'date': datetime.datetime(2018, 8, 12, 4, 0),
#    'listing_id': '1003530',
#    'reviewer_id': '174551190',
#    'reviewer_name': 'Elena',
#    'comments': 'greta was a super host! the house really nice and well kept. the bed is very comfortable and equipped with everything. the neighborhood is very safe and close to all amenities: the metro, supermarkets, main attractions, restaurants. Greta made sure that my stay was unforgettable, always present but never intrusive and respectful of privacy. it has always been helpful for every kind of need. thanks to greta for making my stay beautiful. surely if i go back to new york i will definitely come back here.'}]}

# %%
pd.set_option('display.max_columns', 500)

# %%
airbnb = pd.DataFrame(data)
#airbnb

# %%
airbnb.to_csv('airbnb.csv', index=False)

# %%
airbnb_1 = pd.read_csv('airbnb.csv')
airbnb_1
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10057826  https://www.airbnb.com/rooms/10057826
# 2     10051164  https://www.airbnb.com/rooms/10051164
# 3     10030955  https://www.airbnb.com/rooms/10030955
# 4     10059244  https://www.airbnb.com/rooms/10059244
# ...        ...                                    ...
# 5550   9834391   https://www.airbnb.com/rooms/9834391
# 5551   9867316   https://www.airbnb.com/rooms/9867316
# 5552   9907907   https://www.airbnb.com/rooms/9907907
# 5553   9917859   https://www.airbnb.com/rooms/9917859
# 5554   9985696   https://www.airbnb.com/rooms/9985696
#
#                                                   name  \
# 0                  New York City - Upper West Side Apt
# 1                                    Deluxe Loft Suite
# 2                   Catete's Colonial Big Hause Room B
# 3                          Apt Linda Vista Lagoa - Rio
# 4     Ligne verte - à 15 min de métro du centre ville.
# ...                                                ...
# 5550  Lindo apto quarto e sala ao lado do mar de Copa!
# 5551        Beautiful Place in the Middle of Manhattan
# 5552                        Large double room in Bondi
# 5553                  StayIN Oporto Música - Apartment
# 5554                                   Kadıköy-Altıyol
#
#                                                 summary  \
# 0                                                   NaN
# 1     Loft Suite Deluxe @ Henry Norman Hotel Located...
# 2     Old floor, intirely reformed, destined to rece...
# 3     Quarto com vista para a Lagoa Rodrigo de Freit...
# 4     À 30 secondes du métro Joliette. Belle grande ...
# ...                                                 ...
# 5550  Lindo apartamento todo novinho, quarto (de cas...
# 5551  Beautiful place only a couple blocks from main...
# 5552  A bright large double room is available in a b...
# 5553  Acabamos de decorar-lo para receber os primeir...
# 5554  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
#
#                                                   space  \
# 0     Murphy bed, optional second bedroom available....
# 1     This loft unit features a kitchenette and is f...
# 2     Este quarto está preparado para acomodar confo...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5550  Apto tem tudo o que o hóspede pode precisar, t...
# 5551                                                NaN
# 5552                                                NaN
# 5553                                                NaN
# 5554                                                NaN
#
#                                             description  \
# 0     Murphy bed, optional second bedroom available....
# 1     Loft Suite Deluxe @ Henry Norman Hotel Located...
# 2     Old floor, intirely reformed, destined to rece...
# 3     Quarto com vista para a Lagoa Rodrigo de Freit...
# 4     À 30 secondes du métro Joliette. Belle grande ...
# ...                                                 ...
# 5550  Lindo apartamento todo novinho, quarto (de cas...
# 5551  Beautiful place only a couple blocks from main...
# 5552  A bright large double room is available in a b...
# 5553  Acabamos de decorar-lo para receber os primeir...
# 5554  Kadıköy merkezde 2+1 dairem vardır.Çok kalabal...
#
#                                   neighborhood_overview  \
# 0     Great neighborhood - many terrific restaurants...
# 1     Greenpoint is an artsy Brooklyn neighborhood f...
# 2     A Grande Morada situa-se no Bairro do Catete, ...
# 3                                                   NaN
# 4     L'appartement se trouve à 4 minutes de marche ...
# ...                                                 ...
# 5550  Staying at this apartment you will find everyt...
# 5551                                       Central Park
# 5552                                                NaN
# 5553                                                NaN
# 5554                                                NaN
#
#                                                   notes  \
# 0     My cat, Samantha, are in and out during the su...
# 1                                                   NaN
# 2     A casa possui um potencial incrível para receb...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5550                                                NaN
# 5551                                                NaN
# 5552                                                NaN
# 5553                                                NaN
# 5554                                                NaN
#
#                                                 transit  \
# 0     Conveniently located near 1, 2, 3, B & C subwa...
# 1                                                   NaN
# 2     Perto do metrô e várias linhas de ônibus. Aces...
# 3                                                   NaN
# 4     Stationnement dans la rue, à 30 secondes du mé...
# ...                                                 ...
# 5550  This apartment is located at the heart of Copa...
# 5551                                                NaN
# 5552  The flat is exactly half way between the shops...
# 5553                                                NaN
# 5554                                                NaN
#
#                                                  access  \
# 0                                        New York City!
# 1     Guest will have access to common terraces, lou...
# 2     O hóspedes poderão acessar espaços compartilha...
# 3                                                   NaN
# 4                 Vous avez accès à tout l'appartement.
# ...                                                 ...
# 5550  You will have access to the whole apartment  a...
# 5551                                                NaN
# 5552  Guests will have access to the full residence,...
# 5553                                                NaN
# 5554                                                NaN
#
#                                             interaction  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Sou geógrafa, gosto de arte e cultura. Moro ne...
# 3                                                   NaN
# 4            Une amie sera disponible en cas de besoin.
# ...                                                 ...
# 5550  Eu como anfitriã estarei a disposição para res...
# 5551                                                NaN
# 5552  I will be spending the whole of the Easter per...
# 5553                                                NaN
# 5554                                                NaN
#
#                                             house_rules property_type  \
# 0     No smoking is permitted in the apartment. All ...     Apartment
# 1     Guest must leave a copy of credit card with fr...     Apartment
# 2                                                   NaN         House
# 3                                                   NaN     Apartment
# 4     Non fumeur Respect des voisins Respect des bie...     Apartment
# ...                                                 ...           ...
# 5550                                                NaN     Apartment
# 5551  1. NO smoking 2. NO outside guests 3. Please t...     Apartment
# 5552  We like to keep the flat clean and tidy so wou...     Apartment
# 5553                                                NaN     Apartment
# 5554                                                NaN         House
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed              12             360
# 1     Entire home/apt  Real Bed               3            1125
# 2        Private room  Real Bed               2            1125
# 3        Private room  Real Bed               1            1125
# 4     Entire home/apt  Real Bed               2            1125
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed               2            1125
# 5551  Entire home/apt  Real Bed               1            1125
# 5552     Private room  Real Bed               3            1125
# 5553  Entire home/apt  Real Bed               1            1125
# 5554  Entire home/apt  Real Bed               1            1125
#
#               cancellation_policy         last_scraped calendar_last_scraped  \
# 0     strict_14_with_grace_period  2019-03-07 05:00:00   2019-03-07 05:00:00
# 1     strict_14_with_grace_period  2019-03-07 05:00:00   2019-03-07 05:00:00
# 2     strict_14_with_grace_period  2019-02-11 05:00:00   2019-02-11 05:00:00
# 3                        flexible  2019-02-11 05:00:00   2019-02-11 05:00:00
# 4                        moderate  2019-03-11 04:00:00   2019-03-11 04:00:00
# ...                           ...                  ...                   ...
# 5550  strict_14_with_grace_period  2019-02-11 05:00:00   2019-02-11 05:00:00
# 5551  strict_14_with_grace_period  2019-03-07 05:00:00   2019-03-07 05:00:00
# 5552                     moderate  2019-03-07 05:00:00   2019-03-07 05:00:00
# 5553  strict_14_with_grace_period  2019-02-16 05:00:00   2019-02-16 05:00:00
# 5554                     flexible  2019-02-18 05:00:00   2019-02-18 05:00:00
#
#              first_review          last_review  accommodates  bedrooms  beds  \
# 0     2013-04-29 04:00:00  2018-08-12 04:00:00             2       1.0   1.0
# 1     2016-01-03 05:00:00  2018-02-18 05:00:00             4       0.0   2.0
# 2     2016-02-10 05:00:00  2016-02-10 05:00:00             8       1.0   8.0
# 3                     NaN                  NaN             2       1.0   1.0
# 4                     NaN                  NaN             2       0.0   1.0
# ...                   ...                  ...           ...       ...   ...
# 5550  2017-11-04 04:00:00  2019-02-04 05:00:00             4       1.0   2.0
# 5551  2016-02-11 05:00:00  2019-02-16 05:00:00             2       1.0   1.0
# 5552                  NaN                  NaN             2       1.0   1.0
# 5553  2016-05-08 04:00:00  2019-01-02 05:00:00            16       8.0   8.0
# 5554                  NaN                  NaN             2       2.0   3.0
#
#       number_of_reviews  bathrooms  \
# 0                    70        1.0
# 1                     5        1.0
# 2                     1        4.0
# 3                     0        2.0
# 4                     0        1.0
# ...                 ...        ...
# 5550                 19        1.0
# 5551                180        1.0
# 5552                  0        1.0
# 5553                 20        4.0
# 5554                  0        1.0
#
#                                               amenities  price  \
# 0     ['Internet', 'Wifi', 'Air conditioning', 'Kitc...  135.0
# 1     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...  205.0
# 2     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...  250.0
# 3     ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...  701.0
# 4     ['TV', 'Internet', 'Wifi', 'Kitchen', 'Free pa...   43.0
# ...                                                 ...    ...
# 5550  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Air co...  119.0
# 5551  ['Wifi', 'Air conditioning', 'Kitchen', 'Pets ...  160.0
# 5552  ['TV', 'Internet', 'Wifi', 'Kitchen', 'Washer'...   60.0
# 5553  ['TV', 'Cable TV', 'Wifi', 'Kitchen', 'Elevato...  500.0
# 5554  ['TV', 'Cable TV', 'Internet', 'Wifi', 'Kitche...  501.0
#
#       security_deposit  cleaning_fee  extra_people  guests_included  \
# 0                  0.0         135.0           0.0                1
# 1                  NaN           NaN           0.0                1
# 2                  0.0           0.0          40.0                4
# 3               1000.0         250.0           0.0                1
# 4                  NaN           NaN          12.0                1
# ...                ...           ...           ...              ...
# 5550               0.0         150.0           0.0                1
# 5551             250.0          40.0          20.0                2
# 5552               NaN          50.0          50.0                2
# 5553             200.0          80.0          30.0               16
# 5554               NaN           NaN           0.0                1
#
#                                                  images  \
# 0     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4     {'thumbnail_url': '', 'medium_url': '', 'pictu...
# ...                                                 ...
# 5550  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5551  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5552  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5553  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 5554  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                    host  \
# 0     {'host_id': '454250', 'host_url': 'https://www...
# 1     {'host_id': '47554473', 'host_url': 'https://w...
# 2     {'host_id': '51326285', 'host_url': 'https://w...
# 3     {'host_id': '51496939', 'host_url': 'https://w...
# 4     {'host_id': '7140229', 'host_url': 'https://ww...
# ...                                                 ...
# 5550  {'host_id': '1403065', 'host_url': 'https://ww...
# 5551  {'host_id': '40540485', 'host_url': 'https://w...
# 5552  {'host_id': '47615848', 'host_url': 'https://w...
# 5553  {'host_id': '2296185', 'host_url': 'https://ww...
# 5554  {'host_id': '51303748', 'host_url': 'https://w...
#
#                                                 address  \
# 0     {'street': 'New York, NY, United States', 'sub...
# 1     {'street': 'Brooklyn, NY, United States', 'sub...
# 2     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4     {'street': 'Montréal, Québec, Canada', 'suburb...
# ...                                                 ...
# 5550  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5551  {'street': 'New York, NY, United States', 'sub...
# 5552  {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 5553  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5554  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
#
#                                            availability  \
# 0     {'availability_30': 0, 'availability_60': 0, '...
# 1     {'availability_30': 30, 'availability_60': 31,...
# 2     {'availability_30': 10, 'availability_60': 10,...
# 3     {'availability_30': 28, 'availability_60': 58,...
# 4     {'availability_30': 0, 'availability_60': 0, '...
# ...                                                 ...
# 5550  {'availability_30': 17, 'availability_60': 35,...
# 5551  {'availability_30': 2, 'availability_60': 11, ...
# 5552  {'availability_30': 0, 'availability_60': 0, '...
# 5553  {'availability_30': 28, 'availability_60': 54,...
# 5554  {'availability_30': 30, 'availability_60': 60,...
#
#                                           review_scores  \
# 0     {'review_scores_accuracy': 10, 'review_scores_...
# 1     {'review_scores_accuracy': 9, 'review_scores_c...
# 2     {'review_scores_accuracy': 10, 'review_scores_...
# 3                                                    {}
# 4                                                    {}
# ...                                                 ...
# 5550  {'review_scores_accuracy': 10, 'review_scores_...
# 5551  {'review_scores_accuracy': 9, 'review_scores_c...
# 5552                                                 {}
# 5553  {'review_scores_accuracy': 9, 'review_scores_c...
# 5554                                                 {}
#
#                                                 reviews  weekly_price  \
# 0     [{'_id': '4351675', 'date': datetime.datetime(...           NaN
# 1     [{'_id': '58665374', 'date': datetime.datetime...           NaN
# 2     [{'_id': '61992538', 'date': datetime.datetime...           NaN
# 3                                                    []           NaN
# 4                                                    []           NaN
# ...                                                 ...           ...
# 5550  [{'_id': '209162839', 'date': datetime.datetim...           NaN
# 5551  [{'_id': '62108866', 'date': datetime.datetime...           NaN
# 5552                                                 []           NaN
# 5553  [{'_id': '73527641', 'date': datetime.datetime...           NaN
# 5554                                                 []           NaN
#
#       monthly_price  reviews_per_month
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# ...             ...                ...
# 5550            NaN                NaN
# 5551         3999.0                NaN
# 5552            NaN                NaN
# 5553            NaN                NaN
# 5554            NaN                NaN
#
# [5555 rows x 42 columns]

# %%
airbnb_1.drop(columns=['_id','address','host','availability','review_scores','amenities','images','reviews','listing_url',
                       'summary','first_review','last_review','interaction','cleaning_fee','space','description',
                       'neighborhood_overview','notes','transit','house_rules','access','last_scraped',
                       'calendar_last_scraped','security_deposit',],inplace=True)

# %%
airbnb_1.shape
# Out:
# (5555, 18)

# %%
airbnb_1.columns
# Out:
# Index(['name', 'property_type', 'room_type', 'bed_type', 'minimum_nights',
#        'maximum_nights', 'cancellation_policy', 'accommodates', 'bedrooms',
#        'beds', 'number_of_reviews', 'bathrooms', 'price', 'extra_people',
#        'guests_included', 'weekly_price', 'monthly_price',
#        'reviews_per_month'],
#       dtype='object')

# %%
missing_values = airbnb_1.isnull().sum()
print(missing_values)
# Out:
# name                      8
# property_type             0
# room_type                 0
# bed_type                  0
# minimum_nights            0
# maximum_nights            0
# cancellation_policy       0
# accommodates              0
# bedrooms                  5
# beds                     13
# number_of_reviews         0
# bathrooms                10
# price                     0
# extra_people              0
# guests_included           0
# weekly_price           4841
# monthly_price          4899
# reviews_per_month      5461
# dtype: int64

# %%
airbnb_1.drop(columns=['weekly_price','monthly_price','reviews_per_month'], inplace=True)

# %%
# filling the missing values using statistical techniques
airbnb_1 = airbnb_1.fillna({'name':airbnb_1['name'].mode()[0],
                'bedrooms': airbnb_1['bedrooms'].mean(),
                'beds': airbnb_1['beds'].mean(),
                'bathrooms':airbnb_1['bathrooms'].mean()})

# %%
airbnb_1.isnull().sum()
# Out:
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# extra_people           0
# guests_included        0
# dtype: int64

# %% [markdown]
# # Data Type Correction

# %%
airbnb_1.dtypes
# Out:
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int64
# maximum_nights           int64
# cancellation_policy     object
# accommodates             int64
# bedrooms               float64
# beds                   float64
# number_of_reviews        int64
# bathrooms              float64
# price                  float64
# extra_people           float64
# guests_included          int64
# dtype: object

# %%
# correcting data type of columns
airbnb_1['bedrooms'] = airbnb_1['bedrooms'].astype("int64")
airbnb_1['beds'] = airbnb_1['beds'].astype("int64")
airbnb_1['bathrooms'] = airbnb_1['bathrooms'].astype("int64")
airbnb_1['extra_people'] = airbnb_1['extra_people'].astype("int64")

# %%
airbnb_1.dtypes
# Out:
# name                    object
# property_type           object
# room_type               object
# bed_type                object
# minimum_nights           int64
# maximum_nights           int64
# cancellation_policy     object
# accommodates             int64
# bedrooms                 int64
# beds                     int64
# number_of_reviews        int64
# bathrooms                int64
# price                  float64
# extra_people             int64
# guests_included          int64
# dtype: object

# %%
airbnb_1.shape
# Out:
# (5555, 15)

# %%
airbnb_1.drop_duplicates(inplace=True)

# %%
airbnb_1.duplicated().sum()
# Out:
# 0

# %%
airbnb_1.describe()
# Out:
#        minimum_nights  maximum_nights  accommodates     bedrooms         beds  \
# count     5554.000000    5.554000e+03   5554.000000  5554.000000  5554.000000
# mean         5.565178    1.383025e+06      3.506122     1.411415     2.071480
# std         22.615814    5.257393e+07      2.297137     1.041626     1.617849
# min          1.000000    1.000000e+00      1.000000     0.000000     0.000000
# 25%          1.000000    5.900000e+01      2.000000     1.000000     1.000000
# 50%          2.000000    1.125000e+03      3.000000     1.000000     2.000000
# 75%          3.000000    1.125000e+03      4.000000     2.000000     3.000000
# max       1250.000000    2.147484e+09     16.000000    20.000000    25.000000
#
#        number_of_reviews    bathrooms         price  extra_people  \
# count        5554.000000  5554.000000   5554.000000   5554.000000
# mean           27.611451     1.258192    278.774937     22.792942
# std            49.801481     0.683703    842.291108     69.337710
# min             0.000000     0.000000      9.000000      0.000000
# 25%             1.000000     1.000000     70.000000      0.000000
# 50%             5.000000     1.000000    129.000000      0.000000
# 75%            32.000000     1.000000    280.000000     20.000000
# max           533.000000    16.000000  48842.000000   2346.000000
#
#        guests_included
# count      5554.000000
# mean          1.747389
# std           1.487482
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max          16.000000

# %%
Q1 = airbnb_1['minimum_nights'].quantile(0.25)
Q3 = airbnb_1['minimum_nights'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -2.0 6.0

# %%
airbnb_1.minimum_nights=airbnb_1.minimum_nights.clip(upper_bound , lower_bound )

# %%
Q1 = airbnb_1['maximum_nights'].quantile(0.25)
Q3 = airbnb_1['maximum_nights'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -1540.0 2724.0

# %%
Q1 = airbnb_1['accommodates'].quantile(0.25)
Q3 = airbnb_1['accommodates'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -1.0 7.0

# %%
airbnb_1.accommodates=airbnb_1.accommodates.clip(upper_bound , lower_bound )

# %%
Q1 = airbnb_1['bedrooms'].quantile(0.25)
Q3 = airbnb_1['bedrooms'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -0.5 3.5

# %%
airbnb_1.accommodates=airbnb_1.accommodates.clip(upper_bound , lower_bound )

# %%
Q1 = airbnb_1['beds'].quantile(0.25)
Q3 = airbnb_1['beds'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -2.0 6.0

# %%
airbnb_1.beds=airbnb_1.beds.clip(upper_bound , lower_bound )

# %%
Q1 = airbnb_1['number_of_reviews'].quantile(0.25)
Q3 = airbnb_1['number_of_reviews'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -45.5 78.5

# %%
Q1 = airbnb_1['bathrooms'].quantile(0.25)
Q3 = airbnb_1['bathrooms'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# 1.0 1.0

# %%
airbnb_1.bathrooms=airbnb_1.bathrooms.clip(upper_bound , lower_bound )

# %%
airbnb_1.duplicated().sum()
# Out:
# 0

# %%
airbnb_1
# Out:
#                                                   name property_type  \
# 0                  New York City - Upper West Side Apt     Apartment
# 1                                    Deluxe Loft Suite     Apartment
# 2                   Catete's Colonial Big Hause Room B         House
# 3                          Apt Linda Vista Lagoa - Rio     Apartment
# 4     Ligne verte - à 15 min de métro du centre ville.     Apartment
# ...                                                ...           ...
# 5550  Lindo apto quarto e sala ao lado do mar de Copa!     Apartment
# 5551        Beautiful Place in the Middle of Manhattan     Apartment
# 5552                        Large double room in Bondi     Apartment
# 5553                  StayIN Oporto Música - Apartment     Apartment
# 5554                                   Kadıköy-Altıyol         House
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed             6.0             360
# 1     Entire home/apt  Real Bed             3.0            1125
# 2        Private room  Real Bed             2.0            1125
# 3        Private room  Real Bed             1.0            1125
# 4     Entire home/apt  Real Bed             2.0            1125
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed             2.0            1125
# 5551  Entire home/apt  Real Bed             1.0            1125
# 5552     Private room  Real Bed             3.0            1125
# 5553  Entire home/apt  Real Bed             1.0            1125
# 5554  Entire home/apt  Real Bed             1.0            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period           2.0         1   1.0
# 1     strict_14_with_grace_period           3.5         0   2.0
# 2     strict_14_with_grace_period           3.5         1   6.0
# 3                        flexible           2.0         1   1.0
# 4                        moderate           2.0         0   1.0
# ...                           ...           ...       ...   ...
# 5550  strict_14_with_grace_period           3.5         1   2.0
# 5551  strict_14_with_grace_period           2.0         1   1.0
# 5552                     moderate           2.0         1   1.0
# 5553  strict_14_with_grace_period           3.5         8   6.0
# 5554                     flexible           2.0         2   3.0
#
#       number_of_reviews  bathrooms  price  extra_people  guests_included
# 0                    70        1.0  135.0             0                1
# 1                     5        1.0  205.0             0                1
# 2                     1        1.0  250.0            40                4
# 3                     0        1.0  701.0             0                1
# 4                     0        1.0   43.0            12                1
# ...                 ...        ...    ...           ...              ...
# 5550                 19        1.0  119.0             0                1
# 5551                180        1.0  160.0            20                2
# 5552                  0        1.0   60.0            50                2
# 5553                 20        1.0  500.0            30               16
# 5554                  0        1.0  501.0             0                1
#
# [5554 rows x 15 columns]

# %%
airbnb_1.to_csv('airbnb_main.csv', index=False)

# %%
a = pd.DataFrame(airbnb['address'])
a
# Out:
#                                                 address
# 0     {'street': 'New York, NY, United States', 'sub...
# 1     {'street': 'Brooklyn, NY, United States', 'sub...
# 2     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4     {'street': 'Montréal, Québec, Canada', 'suburb...
# ...                                                 ...
# 5550  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5551  {'street': 'New York, NY, United States', 'sub...
# 5552  {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 5553  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5554  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
#
# [5555 rows x 1 columns]

# %%
a.to_csv('address_duplicate.csv', index=False)

# %%
address = pd.read_csv('address_duplicate.csv')
address
# Out:
#                                                 address
# 0     {'street': 'New York, NY, United States', 'sub...
# 1     {'street': 'Brooklyn, NY, United States', 'sub...
# 2     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 3     {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4     {'street': 'Montréal, Québec, Canada', 'suburb...
# ...                                                 ...
# 5550  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 5551  {'street': 'New York, NY, United States', 'sub...
# 5552  {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 5553  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 5554  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
#
# [5555 rows x 1 columns]

# %%
airbnb.address[1].keys()
# Out:
# dict_keys(['street', 'suburb', 'government_area', 'market', 'country', 'country_code', 'location'])

# %%
address = pd.DataFrame(a)


address['street'] = address['address'].apply(lambda x: x['street'])
address['suburb'] = address['address'].apply(lambda x: x['suburb'])
address['government_area'] = address['address'].apply(lambda x: x['government_area'])
address['market'] = address['address'].apply(lambda x: x['market'])
address['country'] = address['address'].apply(lambda x: x['country'])
address['country_code'] = address['address'].apply(lambda x: x['country_code'])
address['type'] = address['address'].apply(lambda x: x['location']['type'])
#address['coordinates'] = address['address'].apply(lambda x: x['location']['coordinates'])
address['Latitude'] = address['address'].apply(lambda x: x['location']['coordinates'][1])
address['Longitude'] = address['address'].apply(lambda x: x['location']['coordinates'][0])
address['is_location_exact'] = address['address'].apply(lambda x: x['location']['is_location_exact'])

# Drop the original 'address' column if not needed
address.drop(columns=['address'], inplace=True)

# %%
print(address['street'].value_counts())
# Out:
# Montréal, Québec, Canada                  492
# Barcelona, Catalunya, Spain               427
# Porto, Porto, Portugal                    351
# Rio de Janeiro, Rio de Janeiro, Brazil    326
# New York, NY, United States               284
#                                          ...
# Watsons Bay, NSW, Australia                 1
# İstanbul, Kağıthane, Turkey                 1
# Roseville, NSW, Australia                   1
# causeway bay , causeway bay, Hong Kong      1
# Waimanalo Beach, HI, United States          1
# Name: street, Length: 677, dtype: int64

# %%
print(address['suburb'].value_counts())
# Out:
#                                  887
# Copacabana                       154
# Manhattan                        148
# Eixample                         140
# Brooklyn                         129
#                                 ...
# Carmel                             1
# Vilapicina i la Torre Llobeta      1
# Waipahu                            1
# Ridgewood                          1
# Carlton                            1
# Name: suburb, Length: 410, dtype: int64

# %%
address.duplicated().sum()
# Out:
# 0

# %%
address = pd.DataFrame(address)

# %%
address.to_csv('address_duplicate.csv', index=False)

# %%
address = pd.read_csv('address_duplicate.csv')
address
# Out:
#                                       street                 suburb  \
# 0                New York, NY, United States              Manhattan
# 1                Brooklyn, NY, United States             Greenpoint
# 2     Rio de Janeiro, Rio de Janeiro, Brazil                 Catete
# 3     Rio de Janeiro, Rio de Janeiro, Brazil                  Lagoa
# 4                   Montréal, Québec, Canada  Hochelaga-Maisonneuve
# ...                                      ...                    ...
# 5550  Rio de Janeiro, Rio de Janeiro, Brazil             Copacabana
# 5551             New York, NY, United States              Manhattan
# 5552             Bondi Beach, NSW, Australia                  Bondi
# 5553                  Porto, Porto, Portugal                    NaN
# 5554               Kadıköy, İstanbul, Turkey                   Moda
#
#                                         government_area          market  \
# 0                                       Upper West Side        New York
# 1                                            Greenpoint        New York
# 2                                                Catete  Rio De Janeiro
# 3                                                 Lagoa  Rio De Janeiro
# 4                         Mercier-Hochelaga-Maisonneuve        Montreal
# ...                                                 ...             ...
# 5550                                         Copacabana  Rio De Janeiro
# 5551                                    Upper East Side        New York
# 5552                                           Waverley          Sydney
# 5553  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 5554                                            Kadikoy        Istanbul
#
#             country country_code   type   Latitude   Longitude  \
# 0     United States           US  Point  40.799620  -73.965230
# 1     United States           US  Point  40.727780  -73.944720
# 2            Brazil           BR  Point -22.926382  -43.180157
# 3            Brazil           BR  Point -22.971951  -43.205047
# 4            Canada           CA  Point  45.545480  -73.549490
# ...             ...          ...    ...        ...         ...
# 5550         Brazil           BR  Point -22.963806  -43.177922
# 5551  United States           US  Point  40.762660  -73.962050
# 5552      Australia           AU  Point -33.892980  151.265420
# 5553       Portugal           PT  Point  41.151270   -8.606220
# 5554         Turkey           TR  Point  40.985630   29.030790
#
#       is_location_exact
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                 False
# ...                 ...
# 5550              False
# 5551               True
# 5552              False
# 5553               True
# 5554              False
#
# [5555 rows x 10 columns]

# %%
df = pd.read_csv('address_duplicate.csv')

# Split the 'street' column by comma and select the first part
#df['street'] = df['street'].str.split(',').str[0]
#df['government_area'] = df['government_area'].str.split(',').str[0]
#df = pd.DataFrame(data)

# Custom function to fill NaN values in 'suburb' using 'market'
def fill_suburb_with_market(row):
    if pd.isna(row['suburb']):
        return row['market']
    else:
        return row['suburb']

# Apply the custom function to fill NaN values in 'suburb' column
df['suburb'] = df.apply(fill_suburb_with_market, axis=1)

# Display the DataFrame with NaN values in 'suburb' filled using 'market'
#print(df)

# %%
df.loc[629, 'suburb'] = "Copacabana"

# %%
missing_values = df.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# street               0
# suburb               1
# government_area      0
# market               6
# country              0
# country_code         0
# type                 0
# Latitude             0
# Longitude            0
# is_location_exact    0
# dtype: int64

# %%
missing_values = df[df['suburb'].isna()]

#Display the row(s) with missing value(s) in the 'suburb' column
print(missing_values)
#df.iloc[629]
# Out:
#                                      street suburb government_area market  \
# 640  Rio de Janeiro, Rio de Janeiro, Brazil    NaN      Copacabana    NaN
#
#     country country_code   type   Latitude  Longitude  is_location_exact
# 640  Brazil           BR  Point -22.975668  -43.19012               True

# %%
df.loc[640, 'suburb'] = "Copacabana"

# %%
df["suburb"]
# Out:
# 0                   Manhattan
# 1                  Greenpoint
# 2                      Catete
# 3                       Lagoa
# 4       Hochelaga-Maisonneuve
#                 ...
# 5550               Copacabana
# 5551                Manhattan
# 5552                    Bondi
# 5553                    Porto
# 5554                     Moda
# Name: suburb, Length: 5555, dtype: object

# %%
missing_values = df[df['market'].isna()]

#Display the row(s) with missing value(s) in the 'suburb' column
print(missing_values)
#df.iloc[629]
# Out:
#                                      street             suburb  \
# 583                Waverley, NSW, Australia            Waverly
# 605             New York, NY, United States          Manhattan
# 640  Rio de Janeiro, Rio de Janeiro, Brazil         Copacabana
# 667                Montréal, Québec, Canada  Downtown Montreal
# 781             Barcelona, Catalunya, Spain     Sants-Montjuïc
# 810                Kapaa, HI, United States             Kauaʻi
#
#      government_area market        country country_code   type   Latitude  \
# 583         Waverley    NaN      Australia           AU  Point -33.902980
# 605  Upper West Side    NaN  United States           US  Point  40.794150
# 640       Copacabana    NaN         Brazil           BR  Point -22.975668
# 667      Ville-Marie    NaN         Canada           CA  Point  45.525880
# 781     el Poble Sec    NaN          Spain           ES  Point  41.372070
# 810     Kapaa-Wailua    NaN  United States           US  Point  22.053230
#
#      Longitude  is_location_exact
# 583  151.25337               True
# 605  -73.97323               True
# 640  -43.19012               True
# 667  -73.55997               True
# 781    2.15659               True
# 810 -159.32794               True

# %%
df.loc[583, 'market'] = "Québec"
df.loc[605, 'market'] = "Copacabana"
df.loc[640, 'market'] = " Waverly"
df.loc[667, 'market'] = "Manhattan"
df.loc[781, 'market'] = "Sants-Montjuïc"
df.loc[810, 'market'] = "Kauaʻi"

# %%
missing_values = df.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# street               0
# suburb               0
# government_area      0
# market               0
# country              0
# country_code         0
# type                 0
# Latitude             0
# Longitude            0
# is_location_exact    0
# dtype: int64

# %%
df['street'] = df['street'].str.split(',').str[0]

# %%
df['government_area'] = df['government_area'].str.split(',').str[0]

# %%
df
# Out:
#               street                 suburb                government_area  \
# 0           New York              Manhattan                Upper West Side
# 1           Brooklyn             Greenpoint                     Greenpoint
# 2     Rio de Janeiro                 Catete                         Catete
# 3     Rio de Janeiro                  Lagoa                          Lagoa
# 4           Montréal  Hochelaga-Maisonneuve  Mercier-Hochelaga-Maisonneuve
# ...              ...                    ...                            ...
# 5550  Rio de Janeiro             Copacabana                     Copacabana
# 5551        New York              Manhattan                Upper East Side
# 5552     Bondi Beach                  Bondi                       Waverley
# 5553           Porto                  Porto                      Cedofeita
# 5554         Kadıköy                   Moda                        Kadikoy
#
#               market        country country_code   type   Latitude  \
# 0           New York  United States           US  Point  40.799620
# 1           New York  United States           US  Point  40.727780
# 2     Rio De Janeiro         Brazil           BR  Point -22.926382
# 3     Rio De Janeiro         Brazil           BR  Point -22.971951
# 4           Montreal         Canada           CA  Point  45.545480
# ...              ...            ...          ...    ...        ...
# 5550  Rio De Janeiro         Brazil           BR  Point -22.963806
# 5551        New York  United States           US  Point  40.762660
# 5552          Sydney      Australia           AU  Point -33.892980
# 5553           Porto       Portugal           PT  Point  41.151270
# 5554        Istanbul         Turkey           TR  Point  40.985630
#
#        Longitude  is_location_exact
# 0     -73.965230              False
# 1     -73.944720               True
# 2     -43.180157               True
# 3     -43.205047               True
# 4     -73.549490              False
# ...          ...                ...
# 5550  -43.177922              False
# 5551  -73.962050               True
# 5552  151.265420              False
# 5553   -8.606220               True
# 5554   29.030790              False
#
# [5555 rows x 10 columns]

# %%
df.to_csv('address_main.csv', index=False)

# %% [markdown]
# #                     HOST

# %%
b = pd.DataFrame(airbnb['host'])
b
# Out:
#                                                    host
# 0     {'host_id': '454250', 'host_url': 'https://www...
# 1     {'host_id': '47554473', 'host_url': 'https://w...
# 2     {'host_id': '51326285', 'host_url': 'https://w...
# 3     {'host_id': '51496939', 'host_url': 'https://w...
# 4     {'host_id': '7140229', 'host_url': 'https://ww...
# ...                                                 ...
# 5550  {'host_id': '1403065', 'host_url': 'https://ww...
# 5551  {'host_id': '40540485', 'host_url': 'https://w...
# 5552  {'host_id': '47615848', 'host_url': 'https://w...
# 5553  {'host_id': '2296185', 'host_url': 'https://ww...
# 5554  {'host_id': '51303748', 'host_url': 'https://w...
#
# [5555 rows x 1 columns]

# %%
b['host'][0]
# Out:
# {'host_id': '454250',
#  'host_url': 'https://www.airbnb.com/users/show/454250',
#  'host_name': 'Greta',
#  'host_location': 'New York, New York, United States',
#  'host_about': 'By now I have lived longer in the city than the country however I feel equally at home in each. I like to keep one foot in each and help others to do the same!',
#  'host_response_time': 'within an hour',
#  'host_thumbnail_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_small',
#  'host_picture_url': 'https://a0.muscache.com/im/pictures/f1022be4-e72a-4b35-b6d2-3d2736ddaff9.jpg?aki_policy=profile_x_medium',
#  'host_neighbourhood': '',
#  'host_response_rate': 100,
#  'host_is_superhost': True,
#  'host_has_profile_pic': True,
#  'host_identity_verified': True,
#  'host_listings_count': 3,
#  'host_total_listings_count': 3,
#  'host_verifications': ['email',
#   'phone',
#   'reviews',
#   'jumio',
#   'offline_government_id',
#   'government_id']}

# %%
host = pd.DataFrame(b)

# Extract 'host_id' and 'host_name' from 'host' dictionary
host['host_id'] = host['host'].apply(lambda x: x['host_id'])
host['host_url'] = host['host'].apply(lambda x: x['host_url'])
host['host_name'] = host['host'].apply(lambda x: x['host_name'])
host['host_location'] = host['host'].apply(lambda x: x['host_location'])
host['host_about'] = host['host'].apply(lambda x: x['host_about'])
host['host_response_time'] = host['host'].apply(lambda x: x.get('host_response_time','null'))
host['host_thumbnail_urlt'] = host['host'].apply(lambda x: x['host_thumbnail_url'])
host['host_picture_url'] = host['host'].apply(lambda x: x['host_picture_url'])
host['host_neighbourhood'] = host['host'].apply(lambda x: x['host_neighbourhood'])
host['host_response_rate'] = host['host'].apply(lambda x: x.get('host_response_rate',0))
host['host_is_superhost'] = host['host'].apply(lambda x: x['host_is_superhost'])
host['host_has_profile_pic'] = host['host'].apply(lambda x: x['host_has_profile_pic'])
host['host_identity_verified'] = host['host'].apply(lambda x: x['host_identity_verified'])
host['host_listings_count'] = host['host'].apply(lambda x: x['host_listings_count'])
host['host_total_listings_count'] = host['host'].apply(lambda x: x['host_total_listings_count'])
#host['host_verifications'] = host['host']['host_verifications'].apply(len)
host['host_verifications'] = host['host'].apply(lambda x: x['host_verifications'])
host['host_verifications'] = host['host_verifications'].apply(len)
# Drop the original 'host' column if not needed
host.drop(columns=['host'], inplace=True)

# Display the updated DataFrame
#print(host)

# %%
host[host['host_id'] == 53319251]
# Out:
# Empty DataFrame
# Columns: [host_id, host_url, host_name, host_location, host_about, host_response_time, host_thumbnail_urlt, host_picture_url, host_neighbourhood, host_response_rate, host_is_superhost, host_has_profile_pic, host_identity_verified, host_listings_count, host_total_listings_count, host_verifications]
# Index: []

# %%
print(host['host_response_time'].value_counts())
print(host['host_response_rate'].value_counts())
# Out:
# within an hour        2715
# null                  1388
# within a few hours     742
# within a day           566
# a few days or more     144
# Name: host_response_time, dtype: int64
# 100    2952
# 0      1485
# 90      133
# 98      109
# 99      104
#        ...
# 47        1
# 17        1
# 42        1
# 30        1
# 84        1
# Name: host_response_rate, Length: 62, dtype: int64

# %%
host.drop_duplicates(inplace=True)

# %%
host.describe()
# Out:
#        host_response_rate  host_listings_count  host_total_listings_count  \
# count         5104.000000          5104.000000                5104.000000
# mean            67.681034             7.173589                   7.173589
# std             44.405540            30.484584                  30.484584
# min              0.000000             0.000000                   0.000000
# 25%              0.000000             1.000000                   1.000000
# 50%            100.000000             2.000000                   2.000000
# 75%            100.000000             4.000000                   4.000000
# max            100.000000          1198.000000                1198.000000
#
#        host_verifications
# count         5104.000000
# mean             4.906544
# std              2.180131
# min              1.000000
# 25%              3.000000
# 50%              5.000000
# 75%              6.000000
# max             12.000000

# %%
Q1 = host['host_response_rate'].quantile(0.25)
Q3 = host['host_response_rate'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-150.0, 250.0)

# %%
host.host_response_rate = host.host_response_rate.clip(upper_bound , lower_bound )

# %%
Q1 = host['host_listings_count'].quantile(0.25)
Q3 = host['host_listings_count'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-3.5, 8.5)

# %%
host.host_total_listings_count = host.host_total_listings_count.clip(upper_bound , lower_bound )

# %%
Q1 = host['host_verifications'].quantile(0.25)
Q3 = host['host_verifications'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


lower_bound ,upper_bound

#print(outliers)
# Out:
# (-1.5, 10.5)

# %%
host.host_verifications = host.host_verifications.clip(upper_bound , lower_bound )

# %%
host = pd.DataFrame(host)
host
# Out:
#        host_id                                    host_url host_name  \
# 0       454250    https://www.airbnb.com/users/show/454250     Greta
# 1     47554473  https://www.airbnb.com/users/show/47554473       Mae
# 2     51326285  https://www.airbnb.com/users/show/51326285   Beatriz
# 3     51496939  https://www.airbnb.com/users/show/51496939     Livia
# 4      7140229   https://www.airbnb.com/users/show/7140229      Caro
# ...        ...                                         ...       ...
# 5550   1403065   https://www.airbnb.com/users/show/1403065  Clarissa
# 5551  40540485  https://www.airbnb.com/users/show/40540485    Miguel
# 5552  47615848  https://www.airbnb.com/users/show/47615848      Lucy
# 5553   2296185   https://www.airbnb.com/users/show/2296185    Manuel
# 5554  51303748  https://www.airbnb.com/users/show/51303748      Eren
#
#                                         host_location  \
# 0                   New York, New York, United States
# 1                                                  US
# 2     Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3                                                  BR
# 4                            Montreal, Quebec, Canada
# ...                                               ...
# 5550           Rio de Janeiro, Rio de Janeiro, Brazil
# 5551                New York, New York, United States
# 5552          Bondi Beach, New South Wales, Australia
# 5553                           Jovim, Porto, Portugal
# 5554                       Kadikoy, Çanakkale, Turkey
#
#                                              host_about  host_response_time  \
# 0     By now I have lived longer in the city than th...      within an hour
# 1                                                        within a few hours
# 2                                                            within an hour
# 3                                                                      null
# 4                                                            within an hour
# ...                                                 ...                 ...
# 5550  I am Brazilian, 39 y.o. live in Rio de Janeiro...      within an hour
# 5551  We are a married couple who loves to travel ev...      within an hour
# 5552                                                                   null
# 5553                                         From Porto  within a few hours
# 5554                                                                   null
#
#                                     host_thumbnail_urlt  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 3     https://a0.muscache.com/im/pictures/b7911710-9...
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...
# 5550  https://a0.muscache.com/im/pictures/8bd5fd4e-3...
# 5551  https://a0.muscache.com/im/pictures/f2065606-7...
# 5552  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5553  https://a0.muscache.com/im/users/2296185/profi...
# 5554  https://a0.muscache.com/im/pictures/89a1b839-2...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...         Greenpoint
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
# 3     https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...                ...
# 5550  https://a0.muscache.com/im/pictures/8bd5fd4e-3...
# 5551  https://a0.muscache.com/im/pictures/f2065606-7...    Upper East Side
# 5552  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5553  https://a0.muscache.com/im/users/2296185/profi...
# 5554  https://a0.muscache.com/im/pictures/89a1b839-2...
#
#       host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                    100               True                  True
# 1                    100              False                  True
# 2                     80              False                  True
# 3                      0              False                  True
# 4                    100              False                  True
# ...                  ...                ...                   ...
# 5550                 100              False                  True
# 5551                 100              False                  True
# 5552                   0              False                  True
# 5553                  90              False                  True
# 5554                   0              False                  True
#
#       host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                       True                    3                        3.0
# 1                      False                   13                        8.5
# 2                       True                    5                        5.0
# 3                      False                    1                        1.0
# 4                      False                    1                        1.0
# ...                      ...                  ...                        ...
# 5550                   False                    2                        2.0
# 5551                    True                    1                        1.0
# 5552                   False                    1                        1.0
# 5553                    True                    3                        3.0
# 5554                   False                    2                        2.0
#
#       host_verifications
# 0                    6.0
# 1                    6.0
# 2                    6.0
# 3                    4.0
# 4                    5.0
# ...                  ...
# 5550                 4.0
# 5551                 5.0
# 5552                 2.0
# 5553                 6.0
# 5554                 2.0
#
# [5104 rows x 16 columns]

# %%
host.to_csv('host_duplicates.csv', index=False)

# %%
df_1 = pd.read_csv('host_duplicates.csv')
df_1
# Out:
#        host_id                                    host_url host_name  \
# 0       454250    https://www.airbnb.com/users/show/454250     Greta
# 1     47554473  https://www.airbnb.com/users/show/47554473       Mae
# 2     51326285  https://www.airbnb.com/users/show/51326285   Beatriz
# 3     51496939  https://www.airbnb.com/users/show/51496939     Livia
# 4      7140229   https://www.airbnb.com/users/show/7140229      Caro
# ...        ...                                         ...       ...
# 5099   1403065   https://www.airbnb.com/users/show/1403065  Clarissa
# 5100  40540485  https://www.airbnb.com/users/show/40540485    Miguel
# 5101  47615848  https://www.airbnb.com/users/show/47615848      Lucy
# 5102   2296185   https://www.airbnb.com/users/show/2296185    Manuel
# 5103  51303748  https://www.airbnb.com/users/show/51303748      Eren
#
#                                         host_location  \
# 0                   New York, New York, United States
# 1                                                  US
# 2     Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3                                                  BR
# 4                            Montreal, Quebec, Canada
# ...                                               ...
# 5099           Rio de Janeiro, Rio de Janeiro, Brazil
# 5100                New York, New York, United States
# 5101          Bondi Beach, New South Wales, Australia
# 5102                           Jovim, Porto, Portugal
# 5103                       Kadikoy, Çanakkale, Turkey
#
#                                              host_about  host_response_time  \
# 0     By now I have lived longer in the city than th...      within an hour
# 1                                                   NaN  within a few hours
# 2                                                   NaN      within an hour
# 3                                                   NaN                 NaN
# 4                                                   NaN      within an hour
# ...                                                 ...                 ...
# 5099  I am Brazilian, 39 y.o. live in Rio de Janeiro...      within an hour
# 5100  We are a married couple who loves to travel ev...      within an hour
# 5101                                                NaN                 NaN
# 5102                                         From Porto  within a few hours
# 5103                                                NaN                 NaN
#
#                                     host_thumbnail_urlt  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 3     https://a0.muscache.com/im/pictures/b7911710-9...
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5102  https://a0.muscache.com/im/users/2296185/profi...
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...                NaN
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...         Greenpoint
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
# 3     https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 4     https://a0.muscache.com/im/pictures/user/c6477...                NaN
# ...                                                 ...                ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...                NaN
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...    Upper East Side
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...                NaN
# 5102  https://a0.muscache.com/im/users/2296185/profi...                NaN
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...                NaN
#
#       host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0                    100               True                  True
# 1                    100              False                  True
# 2                     80              False                  True
# 3                      0              False                  True
# 4                    100              False                  True
# ...                  ...                ...                   ...
# 5099                 100              False                  True
# 5100                 100              False                  True
# 5101                   0              False                  True
# 5102                  90              False                  True
# 5103                   0              False                  True
#
#       host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                       True                    3                        3.0
# 1                      False                   13                        8.5
# 2                       True                    5                        5.0
# 3                      False                    1                        1.0
# 4                      False                    1                        1.0
# ...                      ...                  ...                        ...
# 5099                   False                    2                        2.0
# 5100                    True                    1                        1.0
# 5101                   False                    1                        1.0
# 5102                    True                    3                        3.0
# 5103                   False                    2                        2.0
#
#       host_verifications
# 0                    6.0
# 1                    6.0
# 2                    6.0
# 3                    4.0
# 4                    5.0
# ...                  ...
# 5099                 4.0
# 5100                 5.0
# 5101                 2.0
# 5102                 6.0
# 5103                 2.0
#
# [5104 rows x 16 columns]

# %%
df_1.columns
# Out:
# Index(['host_id', 'host_url', 'host_name', 'host_location', 'host_about',
#        'host_response_time', 'host_thumbnail_urlt', 'host_picture_url',
#        'host_neighbourhood', 'host_response_rate', 'host_is_superhost',
#        'host_has_profile_pic', 'host_identity_verified', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications'],
#       dtype='object')

# %%
df_1.drop(columns=['host_neighbourhood'], inplace=True)

# %%
missing_values = df_1.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   8
# host_about                   2139
# host_response_time           1381
# host_thumbnail_urlt             0
# host_picture_url                0
# host_response_rate              0
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
df_1.drop(columns=['host_response_time'], inplace=True)

# %%
df_1['host_location'].fillna(df_1['host_location'].mode(), inplace=True)

# %%
df_1.dropna(subset=['host_location'],inplace=True)

# %%
missing_values = df_1.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_about                   2131
# host_thumbnail_urlt             0
# host_picture_url                0
# host_response_rate              0
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
df_1
# Out:
#        host_id                                    host_url host_name  \
# 0       454250    https://www.airbnb.com/users/show/454250     Greta
# 1     47554473  https://www.airbnb.com/users/show/47554473       Mae
# 2     51326285  https://www.airbnb.com/users/show/51326285   Beatriz
# 3     51496939  https://www.airbnb.com/users/show/51496939     Livia
# 4      7140229   https://www.airbnb.com/users/show/7140229      Caro
# ...        ...                                         ...       ...
# 5099   1403065   https://www.airbnb.com/users/show/1403065  Clarissa
# 5100  40540485  https://www.airbnb.com/users/show/40540485    Miguel
# 5101  47615848  https://www.airbnb.com/users/show/47615848      Lucy
# 5102   2296185   https://www.airbnb.com/users/show/2296185    Manuel
# 5103  51303748  https://www.airbnb.com/users/show/51303748      Eren
#
#                                         host_location  \
# 0                   New York, New York, United States
# 1                                                  US
# 2     Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3                                                  BR
# 4                            Montreal, Quebec, Canada
# ...                                               ...
# 5099           Rio de Janeiro, Rio de Janeiro, Brazil
# 5100                New York, New York, United States
# 5101          Bondi Beach, New South Wales, Australia
# 5102                           Jovim, Porto, Portugal
# 5103                       Kadikoy, Çanakkale, Turkey
#
#                                              host_about  \
# 0     By now I have lived longer in the city than th...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5099  I am Brazilian, 39 y.o. live in Rio de Janeiro...
# 5100  We are a married couple who loves to travel ev...
# 5101                                                NaN
# 5102                                         From Porto
# 5103                                                NaN
#
#                                     host_thumbnail_urlt  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 3     https://a0.muscache.com/im/pictures/b7911710-9...
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5102  https://a0.muscache.com/im/users/2296185/profi...
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...
#
#                                        host_picture_url  host_response_rate  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...                 100
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...                 100
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...                  80
# 3     https://a0.muscache.com/im/pictures/b7911710-9...                   0
# 4     https://a0.muscache.com/im/pictures/user/c6477...                 100
# ...                                                 ...                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...                 100
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...                 100
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...                   0
# 5102  https://a0.muscache.com/im/users/2296185/profi...                  90
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...                   0
#
#       host_is_superhost  host_has_profile_pic  host_identity_verified  \
# 0                  True                  True                    True
# 1                 False                  True                   False
# 2                 False                  True                    True
# 3                 False                  True                   False
# 4                 False                  True                   False
# ...                 ...                   ...                     ...
# 5099              False                  True                   False
# 5100              False                  True                    True
# 5101              False                  True                   False
# 5102              False                  True                    True
# 5103              False                  True                   False
#
#       host_listings_count  host_total_listings_count  host_verifications
# 0                       3                        3.0                 6.0
# 1                      13                        8.5                 6.0
# 2                       5                        5.0                 6.0
# 3                       1                        1.0                 4.0
# 4                       1                        1.0                 5.0
# ...                   ...                        ...                 ...
# 5099                    2                        2.0                 4.0
# 5100                    1                        1.0                 5.0
# 5101                    1                        1.0                 2.0
# 5102                    3                        3.0                 6.0
# 5103                    2                        2.0                 2.0
#
# [5096 rows x 14 columns]

# %%
df_1.to_csv('host_main.csv', index=False)

# %%
c = pd.DataFrame(airbnb['amenities'])
c
# Out:
#                                               amenities
# 0     [Internet, Wifi, Air conditioning, Kitchen, El...
# 1     [TV, Cable TV, Internet, Wifi, Air conditionin...
# 2     [TV, Cable TV, Internet, Wifi, Air conditionin...
# 3     [TV, Cable TV, Internet, Wifi, Air conditionin...
# 4     [TV, Internet, Wifi, Kitchen, Free parking on ...
# ...                                                 ...
# 5550  [TV, Cable TV, Internet, Wifi, Air conditionin...
# 5551  [Wifi, Air conditioning, Kitchen, Pets allowed...
# 5552  [TV, Internet, Wifi, Kitchen, Washer, Dryer, S...
# 5553  [TV, Cable TV, Wifi, Kitchen, Elevator, Heatin...
# 5554  [TV, Cable TV, Internet, Wifi, Kitchen, Buzzer...
#
# [5555 rows x 1 columns]

# %%
amenities = pd.DataFrame(c)

# Calculate lengths of each 'amenities' list and create a new column
amenities['amenities_length'] = amenities['amenities'].apply(len)

# Print the DataFrame
#print(amenities)
amenities = amenities.drop(columns=['amenities'])
amenities= pd.DataFrame(amenities)
amenities
# Out:
#       amenities_length
# 0                   11
# 1                   23
# 2                   11
# 3                   16
# 4                   13
# ...                ...
# 5550                21
# 5551                32
# 5552                 9
# 5553                15
# 5554                15
#
# [5555 rows x 1 columns]

# %%
amenities.to_csv('amenities', index=False)

# %%
df_2 = pd.read_csv('amenities')
df_2
# Out:
#       amenities_length
# 0                   11
# 1                   23
# 2                   11
# 3                   16
# 4                   13
# ...                ...
# 5550                21
# 5551                32
# 5552                 9
# 5553                15
# 5554                15
#
# [5555 rows x 1 columns]

# %%
d=pd.DataFrame(airbnb['availability'])
d
# Out:
#                                            availability
# 0     {'availability_30': 0, 'availability_60': 0, '...
# 1     {'availability_30': 30, 'availability_60': 31,...
# 2     {'availability_30': 10, 'availability_60': 10,...
# 3     {'availability_30': 28, 'availability_60': 58,...
# 4     {'availability_30': 0, 'availability_60': 0, '...
# ...                                                 ...
# 5550  {'availability_30': 17, 'availability_60': 35,...
# 5551  {'availability_30': 2, 'availability_60': 11, ...
# 5552  {'availability_30': 0, 'availability_60': 0, '...
# 5553  {'availability_30': 28, 'availability_60': 54,...
# 5554  {'availability_30': 30, 'availability_60': 60,...
#
# [5555 rows x 1 columns]

# %%
d['availability'][0]
# Out:
# {'availability_30': 0,
#  'availability_60': 0,
#  'availability_90': 0,
#  'availability_365': 93}

# %%
availability = pd.DataFrame(d)

availability['availability_30'] = availability['availability'].apply(lambda x: x['availability_30'])
availability['availability_60'] = availability['availability'].apply(lambda x: x['availability_60'])
availability['availability_90'] = availability['availability'].apply(lambda x: x['availability_90'])
availability['availability_365'] = availability['availability'].apply(lambda x: x['availability_365'])

availability.drop(columns=['availability'], inplace=True)

# %%
availability.isnull().sum()
# Out:
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
availability.duplicated().sum()
# Out:
# 2684

# %%
availability.drop_duplicates(inplace=True)

# %%
availability.describe()
# Out:
#        availability_30  availability_60  availability_90  availability_365
# count      2871.000000      2871.000000      2871.000000       2871.000000
# mean         11.082201        26.251480        44.379659        200.592825
# std           9.312137        17.874499        25.998366        108.597234
# min           0.000000         0.000000         0.000000          0.000000
# 25%           3.000000        11.000000        23.000000        100.500000
# 50%           9.000000        25.000000        46.000000        216.000000
# 75%          18.000000        41.000000        66.000000        300.500000
# max          30.000000        60.000000        90.000000        365.000000

# %%
Q1 = availability['availability_30'].quantile(0.25)
Q3 = availability['availability_30'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)


print(lower_bound ,upper_bound)
# Out:
# -19.5 40.5

# %%
availability.availability_30 = availability.availability_30.clip(upper_bound , lower_bound )

# %%
Q1 = availability['availability_60'].quantile(0.25)
Q3 = availability['availability_60'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)
print(lower_bound ,upper_bound)
# Out:
# -34.0 86.0

# %%
availability.availability_60 = availability.availability_60.clip(upper_bound , lower_bound )

# %%
Q1 = availability['availability_90'].quantile(0.25)
Q3 = availability['availability_90'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)
print(lower_bound ,upper_bound)
# Out:
# -41.5 130.5

# %%
availability.availability_90 = availability.availability_90.clip(upper_bound , lower_bound)

# %%
Q1 = availability['availability_365'].quantile(0.25)
Q3 = availability['availability_365'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outlier detection
lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)
print(lower_bound ,upper_bound)
# Out:
# -199.5 600.5

# %%
availability.availability_365 = availability.availability_365.clip(upper_bound , lower_bound )

# %%
availability = pd.DataFrame(availability)
availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                   0                0                0                93
# 1                  30               31               31               243
# 2                  10               10               21               296
# 3                  28               58               88               363
# 4                   0                0                0                32
# ...               ...              ...              ...               ...
# 5548                0               15               28               212
# 5549                0                0                0               139
# 5550               17               35               63               322
# 5551                2               11               15               154
# 5553               28               54               82               351
#
# [2871 rows x 4 columns]

# %%
df_3=availability.copy()
df_3
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                   0                0                0                93
# 1                  30               31               31               243
# 2                  10               10               21               296
# 3                  28               58               88               363
# 4                   0                0                0                32
# ...               ...              ...              ...               ...
# 5548                0               15               28               212
# 5549                0                0                0               139
# 5550               17               35               63               322
# 5551                2               11               15               154
# 5553               28               54               82               351
#
# [2871 rows x 4 columns]

# %%
missing_values = df_3.isnull().sum()
#print("Missing Values:")
print(missing_values)
# Out:
# availability_30     0
# availability_60     0
# availability_90     0
# availability_365    0
# dtype: int64

# %%
e = pd.DataFrame(airbnb['review_scores'])
e
# Out:
#                                           review_scores
# 0     {'review_scores_accuracy': 10, 'review_scores_...
# 1     {'review_scores_accuracy': 9, 'review_scores_c...
# 2     {'review_scores_accuracy': 10, 'review_scores_...
# 3                                                    {}
# 4                                                    {}
# ...                                                 ...
# 5550  {'review_scores_accuracy': 10, 'review_scores_...
# 5551  {'review_scores_accuracy': 9, 'review_scores_c...
# 5552                                                 {}
# 5553  {'review_scores_accuracy': 9, 'review_scores_c...
# 5554                                                 {}
#
# [5555 rows x 1 columns]

# %%
rating = pd.DataFrame(e)

# Extract review scores from nested 'review_scores' dictionary
rating['review_scores_accuracy'] = rating['review_scores'].apply(lambda x: x.get('review_scores_accuracy',0))
rating['review_scores_cleanliness'] = rating['review_scores'].apply(lambda x: x.get('review_scores_cleanliness',0))
rating['review_scores_checkin'] = rating['review_scores'].apply(lambda x: x.get('review_scores_checkin',0))
rating['review_scores_communication'] = rating['review_scores'].apply(lambda x: x.get('review_scores_communication',0))
rating['review_scores_location'] = rating['review_scores'].apply(lambda x: x.get('review_scores_location',0))
rating['review_scores_value'] = rating['review_scores'].apply(lambda x: x.get('review_scores_value',0))
rating['review_scores_rating'] = rating['review_scores'].apply(lambda x: x.get('review_scores_rating',0))

# Drop the original 'review_scores' column if not needed
rating.drop(columns=['review_scores'], inplace=True)

# %%
rating.to_csv('rating_dup', index = False)

# %%
df_4 = pd.read_csv("rating_dup")
df_4
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                         10                          9
# 1                          9                         10
# 2                         10                          6
# 3                          0                          0
# 4                          0                          0
# ...                      ...                        ...
# 5550                      10                         10
# 5551                       9                          9
# 5552                       0                          0
# 5553                       9                          9
# 5554                       0                          0
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                           10
# 1                        10                            8
# 2                         8                            8
# 3                         0                            0
# 4                         0                            0
# ...                     ...                          ...
# 5550                     10                           10
# 5551                     10                           10
# 5552                      0                            0
# 5553                      9                            9
# 5554                      0                            0
#
#       review_scores_location  review_scores_value  review_scores_rating
# 0                         10                   10                    94
# 1                          9                    9                    88
# 2                          8                    8                    80
# 3                          0                    0                     0
# 4                          0                    0                     0
# ...                      ...                  ...                   ...
# 5550                      10                   10                    97
# 5551                      10                    9                    92
# 5552                       0                    0                     0
# 5553                       9                    8                    89
# 5554                       0                    0                     0
#
# [5555 rows x 7 columns]

# %%
df_4.isnull().sum()
# Out:
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# review_scores_rating           0
# dtype: int64

# %%
df_4.duplicated().sum()
# Out:
# 4391

# %%
df_4.drop_duplicates(inplace=True)

# %%
airbnb_1
# Out:
#                                                   name property_type  \
# 0                  New York City - Upper West Side Apt     Apartment
# 1                                    Deluxe Loft Suite     Apartment
# 2                   Catete's Colonial Big Hause Room B         House
# 3                          Apt Linda Vista Lagoa - Rio     Apartment
# 4     Ligne verte - à 15 min de métro du centre ville.     Apartment
# ...                                                ...           ...
# 5550  Lindo apto quarto e sala ao lado do mar de Copa!     Apartment
# 5551        Beautiful Place in the Middle of Manhattan     Apartment
# 5552                        Large double room in Bondi     Apartment
# 5553                  StayIN Oporto Música - Apartment     Apartment
# 5554                                   Kadıköy-Altıyol         House
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed             6.0             360
# 1     Entire home/apt  Real Bed             3.0            1125
# 2        Private room  Real Bed             2.0            1125
# 3        Private room  Real Bed             1.0            1125
# 4     Entire home/apt  Real Bed             2.0            1125
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed             2.0            1125
# 5551  Entire home/apt  Real Bed             1.0            1125
# 5552     Private room  Real Bed             3.0            1125
# 5553  Entire home/apt  Real Bed             1.0            1125
# 5554  Entire home/apt  Real Bed             1.0            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period           2.0         1   1.0
# 1     strict_14_with_grace_period           3.5         0   2.0
# 2     strict_14_with_grace_period           3.5         1   6.0
# 3                        flexible           2.0         1   1.0
# 4                        moderate           2.0         0   1.0
# ...                           ...           ...       ...   ...
# 5550  strict_14_with_grace_period           3.5         1   2.0
# 5551  strict_14_with_grace_period           2.0         1   1.0
# 5552                     moderate           2.0         1   1.0
# 5553  strict_14_with_grace_period           3.5         8   6.0
# 5554                     flexible           2.0         2   3.0
#
#       number_of_reviews  bathrooms  price  extra_people  guests_included
# 0                    70        1.0  135.0             0                1
# 1                     5        1.0  205.0             0                1
# 2                     1        1.0  250.0            40                4
# 3                     0        1.0  701.0             0                1
# 4                     0        1.0   43.0            12                1
# ...                 ...        ...    ...           ...              ...
# 5550                 19        1.0  119.0             0                1
# 5551                180        1.0  160.0            20                2
# 5552                  0        1.0   60.0            50                2
# 5553                 20        1.0  500.0            30               16
# 5554                  0        1.0  501.0             0                1
#
# [5554 rows x 15 columns]

# %%
df #address
# Out:
#               street                 suburb                government_area  \
# 0           New York              Manhattan                Upper West Side
# 1           Brooklyn             Greenpoint                     Greenpoint
# 2     Rio de Janeiro                 Catete                         Catete
# 3     Rio de Janeiro                  Lagoa                          Lagoa
# 4           Montréal  Hochelaga-Maisonneuve  Mercier-Hochelaga-Maisonneuve
# ...              ...                    ...                            ...
# 5550  Rio de Janeiro             Copacabana                     Copacabana
# 5551        New York              Manhattan                Upper East Side
# 5552     Bondi Beach                  Bondi                       Waverley
# 5553           Porto                  Porto                      Cedofeita
# 5554         Kadıköy                   Moda                        Kadikoy
#
#               market        country country_code   type   Latitude  \
# 0           New York  United States           US  Point  40.799620
# 1           New York  United States           US  Point  40.727780
# 2     Rio De Janeiro         Brazil           BR  Point -22.926382
# 3     Rio De Janeiro         Brazil           BR  Point -22.971951
# 4           Montreal         Canada           CA  Point  45.545480
# ...              ...            ...          ...    ...        ...
# 5550  Rio De Janeiro         Brazil           BR  Point -22.963806
# 5551        New York  United States           US  Point  40.762660
# 5552          Sydney      Australia           AU  Point -33.892980
# 5553           Porto       Portugal           PT  Point  41.151270
# 5554        Istanbul         Turkey           TR  Point  40.985630
#
#        Longitude  is_location_exact
# 0     -73.965230              False
# 1     -73.944720               True
# 2     -43.180157               True
# 3     -43.205047               True
# 4     -73.549490              False
# ...          ...                ...
# 5550  -43.177922              False
# 5551  -73.962050               True
# 5552  151.265420              False
# 5553   -8.606220               True
# 5554   29.030790              False
#
# [5555 rows x 10 columns]

# %%
df_1  #host
# Out:
#        host_id                                    host_url host_name  \
# 0       454250    https://www.airbnb.com/users/show/454250     Greta
# 1     47554473  https://www.airbnb.com/users/show/47554473       Mae
# 2     51326285  https://www.airbnb.com/users/show/51326285   Beatriz
# 3     51496939  https://www.airbnb.com/users/show/51496939     Livia
# 4      7140229   https://www.airbnb.com/users/show/7140229      Caro
# ...        ...                                         ...       ...
# 5099   1403065   https://www.airbnb.com/users/show/1403065  Clarissa
# 5100  40540485  https://www.airbnb.com/users/show/40540485    Miguel
# 5101  47615848  https://www.airbnb.com/users/show/47615848      Lucy
# 5102   2296185   https://www.airbnb.com/users/show/2296185    Manuel
# 5103  51303748  https://www.airbnb.com/users/show/51303748      Eren
#
#                                         host_location  \
# 0                   New York, New York, United States
# 1                                                  US
# 2     Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3                                                  BR
# 4                            Montreal, Quebec, Canada
# ...                                               ...
# 5099           Rio de Janeiro, Rio de Janeiro, Brazil
# 5100                New York, New York, United States
# 5101          Bondi Beach, New South Wales, Australia
# 5102                           Jovim, Porto, Portugal
# 5103                       Kadikoy, Çanakkale, Turkey
#
#                                              host_about  \
# 0     By now I have lived longer in the city than th...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5099  I am Brazilian, 39 y.o. live in Rio de Janeiro...
# 5100  We are a married couple who loves to travel ev...
# 5101                                                NaN
# 5102                                         From Porto
# 5103                                                NaN
#
#                                     host_thumbnail_urlt  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 3     https://a0.muscache.com/im/pictures/b7911710-9...
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5102  https://a0.muscache.com/im/users/2296185/profi...
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...
#
#                                        host_picture_url  host_response_rate  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...                 100
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...                 100
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...                  80
# 3     https://a0.muscache.com/im/pictures/b7911710-9...                   0
# 4     https://a0.muscache.com/im/pictures/user/c6477...                 100
# ...                                                 ...                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...                 100
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...                 100
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...                   0
# 5102  https://a0.muscache.com/im/users/2296185/profi...                  90
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...                   0
#
#       host_is_superhost  host_has_profile_pic  host_identity_verified  \
# 0                  True                  True                    True
# 1                 False                  True                   False
# 2                 False                  True                    True
# 3                 False                  True                   False
# 4                 False                  True                   False
# ...                 ...                   ...                     ...
# 5099              False                  True                   False
# 5100              False                  True                    True
# 5101              False                  True                   False
# 5102              False                  True                    True
# 5103              False                  True                   False
#
#       host_listings_count  host_total_listings_count  host_verifications
# 0                       3                        3.0                 6.0
# 1                      13                        8.5                 6.0
# 2                       5                        5.0                 6.0
# 3                       1                        1.0                 4.0
# 4                       1                        1.0                 5.0
# ...                   ...                        ...                 ...
# 5099                    2                        2.0                 4.0
# 5100                    1                        1.0                 5.0
# 5101                    1                        1.0                 2.0
# 5102                    3                        3.0                 6.0
# 5103                    2                        2.0                 2.0
#
# [5096 rows x 14 columns]

# %%
df_2  #amenities
# Out:
#       amenities_length
# 0                   11
# 1                   23
# 2                   11
# 3                   16
# 4                   13
# ...                ...
# 5550                21
# 5551                32
# 5552                 9
# 5553                15
# 5554                15
#
# [5555 rows x 1 columns]

# %%
df_3  #availability
# Out:
#       availability_30  availability_60  availability_90  availability_365
# 0                   0                0                0                93
# 1                  30               31               31               243
# 2                  10               10               21               296
# 3                  28               58               88               363
# 4                   0                0                0                32
# ...               ...              ...              ...               ...
# 5548                0               15               28               212
# 5549                0                0                0               139
# 5550               17               35               63               322
# 5551                2               11               15               154
# 5553               28               54               82               351
#
# [2871 rows x 4 columns]

# %%
df_4  #reviews
# Out:
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                         10                          9
# 1                          9                         10
# 2                         10                          6
# 3                          0                          0
# 5                         10                         10
# ...                      ...                        ...
# 5521                      10                          4
# 5526                      10                         10
# 5529                       9                          8
# 5538                      10                         10
# 5545                       8                          9
#
#       review_scores_checkin  review_scores_communication  \
# 0                        10                           10
# 1                        10                            8
# 2                         8                            8
# 3                         0                            0
# 5                        10                           10
# ...                     ...                          ...
# 5521                      8                            6
# 5526                     10                            8
# 5529                      9                            9
# 5538                      8                            8
# 5545                     10                           10
#
#       review_scores_location  review_scores_value  review_scores_rating
# 0                         10                   10                    94
# 1                          9                    9                    88
# 2                          8                    8                    80
# 3                          0                    0                     0
# 5                         10                    8                   100
# ...                      ...                  ...                   ...
# 5521                      10                   10                    60
# 5526                      10                   10                    80
# 5529                       8                    9                    79
# 5538                       8                   10                    80
# 5545                       8                    7                    80
#
# [1164 rows x 7 columns]

# %%
airbnb_1
# Out:
#                                                   name property_type  \
# 0                  New York City - Upper West Side Apt     Apartment
# 1                                    Deluxe Loft Suite     Apartment
# 2                   Catete's Colonial Big Hause Room B         House
# 3                          Apt Linda Vista Lagoa - Rio     Apartment
# 4     Ligne verte - à 15 min de métro du centre ville.     Apartment
# ...                                                ...           ...
# 5550  Lindo apto quarto e sala ao lado do mar de Copa!     Apartment
# 5551        Beautiful Place in the Middle of Manhattan     Apartment
# 5552                        Large double room in Bondi     Apartment
# 5553                  StayIN Oporto Música - Apartment     Apartment
# 5554                                   Kadıköy-Altıyol         House
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed             6.0             360
# 1     Entire home/apt  Real Bed             3.0            1125
# 2        Private room  Real Bed             2.0            1125
# 3        Private room  Real Bed             1.0            1125
# 4     Entire home/apt  Real Bed             2.0            1125
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed             2.0            1125
# 5551  Entire home/apt  Real Bed             1.0            1125
# 5552     Private room  Real Bed             3.0            1125
# 5553  Entire home/apt  Real Bed             1.0            1125
# 5554  Entire home/apt  Real Bed             1.0            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period           2.0         1   1.0
# 1     strict_14_with_grace_period           3.5         0   2.0
# 2     strict_14_with_grace_period           3.5         1   6.0
# 3                        flexible           2.0         1   1.0
# 4                        moderate           2.0         0   1.0
# ...                           ...           ...       ...   ...
# 5550  strict_14_with_grace_period           3.5         1   2.0
# 5551  strict_14_with_grace_period           2.0         1   1.0
# 5552                     moderate           2.0         1   1.0
# 5553  strict_14_with_grace_period           3.5         8   6.0
# 5554                     flexible           2.0         2   3.0
#
#       number_of_reviews  bathrooms  price  extra_people  guests_included
# 0                    70        1.0  135.0             0                1
# 1                     5        1.0  205.0             0                1
# 2                     1        1.0  250.0            40                4
# 3                     0        1.0  701.0             0                1
# 4                     0        1.0   43.0            12                1
# ...                 ...        ...    ...           ...              ...
# 5550                 19        1.0  119.0             0                1
# 5551                180        1.0  160.0            20                2
# 5552                  0        1.0   60.0            50                2
# 5553                 20        1.0  500.0            30               16
# 5554                  0        1.0  501.0             0                1
#
# [5554 rows x 15 columns]

# %%
import seaborn as sns
tc=airbnb_1.groupby(['property_type'])['price'].sum().sort_values(ascending=False).nlargest(10).to_frame()

# %%
tc=tc.reset_index()
tc
# Out:
#         property_type     price
# 0           Apartment  925800.0
# 1               House  202404.0
# 2         Condominium  136810.0
# 3  Serviced apartment   80773.0
# 4   Bed and breakfast   33187.0
# 5                Loft   27784.0
# 6               Hotel   20576.0
# 7           Townhouse   19764.0
# 8      Boutique hotel   16192.0
# 9               Villa   15358.0

# %%
airbnb_data10=pd.concat([airbnb_1,df,df_1,df_2,df_3,df_4],axis=1)

# %%
airbnb_data10
# Out:
#                                                   name property_type  \
# 0                  New York City - Upper West Side Apt     Apartment
# 1                                    Deluxe Loft Suite     Apartment
# 2                   Catete's Colonial Big Hause Room B         House
# 3                          Apt Linda Vista Lagoa - Rio     Apartment
# 4     Ligne verte - à 15 min de métro du centre ville.     Apartment
# ...                                                ...           ...
# 5551        Beautiful Place in the Middle of Manhattan     Apartment
# 5552                        Large double room in Bondi     Apartment
# 5553                  StayIN Oporto Música - Apartment     Apartment
# 5554                                   Kadıköy-Altıyol         House
# 4296                                               NaN           NaN
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed             6.0           360.0
# 1     Entire home/apt  Real Bed             3.0          1125.0
# 2        Private room  Real Bed             2.0          1125.0
# 3        Private room  Real Bed             1.0          1125.0
# 4     Entire home/apt  Real Bed             2.0          1125.0
# ...               ...       ...             ...             ...
# 5551  Entire home/apt  Real Bed             1.0          1125.0
# 5552     Private room  Real Bed             3.0          1125.0
# 5553  Entire home/apt  Real Bed             1.0          1125.0
# 5554  Entire home/apt  Real Bed             1.0          1125.0
# 4296              NaN       NaN             NaN             NaN
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period           2.0       1.0   1.0
# 1     strict_14_with_grace_period           3.5       0.0   2.0
# 2     strict_14_with_grace_period           3.5       1.0   6.0
# 3                        flexible           2.0       1.0   1.0
# 4                        moderate           2.0       0.0   1.0
# ...                           ...           ...       ...   ...
# 5551  strict_14_with_grace_period           2.0       1.0   1.0
# 5552                     moderate           2.0       1.0   1.0
# 5553  strict_14_with_grace_period           3.5       8.0   6.0
# 5554                     flexible           2.0       2.0   3.0
# 4296                          NaN           NaN       NaN   NaN
#
#       number_of_reviews  bathrooms  price  extra_people  guests_included  \
# 0                  70.0        1.0  135.0           0.0              1.0
# 1                   5.0        1.0  205.0           0.0              1.0
# 2                   1.0        1.0  250.0          40.0              4.0
# 3                   0.0        1.0  701.0           0.0              1.0
# 4                   0.0        1.0   43.0          12.0              1.0
# ...                 ...        ...    ...           ...              ...
# 5551              180.0        1.0  160.0          20.0              2.0
# 5552                0.0        1.0   60.0          50.0              2.0
# 5553               20.0        1.0  500.0          30.0             16.0
# 5554                0.0        1.0  501.0           0.0              1.0
# 4296                NaN        NaN    NaN           NaN              NaN
#
#               street                 suburb                government_area  \
# 0           New York              Manhattan                Upper West Side
# 1           Brooklyn             Greenpoint                     Greenpoint
# 2     Rio de Janeiro                 Catete                         Catete
# 3     Rio de Janeiro                  Lagoa                          Lagoa
# 4           Montréal  Hochelaga-Maisonneuve  Mercier-Hochelaga-Maisonneuve
# ...              ...                    ...                            ...
# 5551        New York              Manhattan                Upper East Side
# 5552     Bondi Beach                  Bondi                       Waverley
# 5553           Porto                  Porto                      Cedofeita
# 5554         Kadıköy                   Moda                        Kadikoy
# 4296        Honolulu               Honolulu           Primary Urban Center
#
#               market        country country_code   type   Latitude  \
# 0           New York  United States           US  Point  40.799620
# 1           New York  United States           US  Point  40.727780
# 2     Rio De Janeiro         Brazil           BR  Point -22.926382
# 3     Rio De Janeiro         Brazil           BR  Point -22.971951
# 4           Montreal         Canada           CA  Point  45.545480
# ...              ...            ...          ...    ...        ...
# 5551        New York  United States           US  Point  40.762660
# 5552          Sydney      Australia           AU  Point -33.892980
# 5553           Porto       Portugal           PT  Point  41.151270
# 5554        Istanbul         Turkey           TR  Point  40.985630
# 4296            Oahu  United States           US  Point  21.285550
#
#        Longitude  is_location_exact     host_id  \
# 0     -73.965230              False    454250.0
# 1     -73.944720               True  47554473.0
# 2     -43.180157               True  51326285.0
# 3     -43.205047               True  51496939.0
# 4     -73.549490              False   7140229.0
# ...          ...                ...         ...
# 5551  -73.962050               True         NaN
# 5552  151.265420              False         NaN
# 5553   -8.606220               True         NaN
# 5554   29.030790              False         NaN
# 4296 -157.839230              False   5829222.0
#
#                                         host_url host_name  \
# 0       https://www.airbnb.com/users/show/454250     Greta
# 1     https://www.airbnb.com/users/show/47554473       Mae
# 2     https://www.airbnb.com/users/show/51326285   Beatriz
# 3     https://www.airbnb.com/users/show/51496939     Livia
# 4      https://www.airbnb.com/users/show/7140229      Caro
# ...                                          ...       ...
# 5551                                         NaN       NaN
# 5552                                         NaN       NaN
# 5553                                         NaN       NaN
# 5554                                         NaN       NaN
# 4296   https://www.airbnb.com/users/show/5829222      Muge
#
#                                         host_location  \
# 0                   New York, New York, United States
# 1                                                  US
# 2     Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3                                                  BR
# 4                            Montreal, Quebec, Canada
# ...                                               ...
# 5551                                              NaN
# 5552                                              NaN
# 5553                                              NaN
# 5554                                              NaN
# 4296                                         Istanbul
#
#                                              host_about  \
# 0     By now I have lived longer in the city than th...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5551                                                NaN
# 5552                                                NaN
# 5553                                                NaN
# 5554                                                NaN
# 4296  I am a travel addict! I travelled all around t...
#
#                                     host_thumbnail_urlt  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 3     https://a0.muscache.com/im/pictures/b7911710-9...
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...
# 5551                                                NaN
# 5552                                                NaN
# 5553                                                NaN
# 5554                                                NaN
# 4296  https://a0.muscache.com/im/users/5829222/profi...
#
#                                        host_picture_url  host_response_rate  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...               100.0
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...               100.0
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...                80.0
# 3     https://a0.muscache.com/im/pictures/b7911710-9...                 0.0
# 4     https://a0.muscache.com/im/pictures/user/c6477...               100.0
# ...                                                 ...                 ...
# 5551                                                NaN                 NaN
# 5552                                                NaN                 NaN
# 5553                                                NaN                 NaN
# 5554                                                NaN                 NaN
# 4296  https://a0.muscache.com/im/users/5829222/profi...                92.0
#
#      host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                 True                 True                   True
# 1                False                 True                  False
# 2                False                 True                   True
# 3                False                 True                  False
# 4                False                 True                  False
# ...                ...                  ...                    ...
# 5551               NaN                  NaN                    NaN
# 5552               NaN                  NaN                    NaN
# 5553               NaN                  NaN                    NaN
# 5554               NaN                  NaN                    NaN
# 4296             False                 True                   True
#
#       host_listings_count  host_total_listings_count  host_verifications  \
# 0                     3.0                        3.0                 6.0
# 1                    13.0                        8.5                 6.0
# 2                     5.0                        5.0                 6.0
# 3                     1.0                        1.0                 4.0
# 4                     1.0                        1.0                 5.0
# ...                   ...                        ...                 ...
# 5551                  NaN                        NaN                 NaN
# 5552                  NaN                        NaN                 NaN
# 5553                  NaN                        NaN                 NaN
# 5554                  NaN                        NaN                 NaN
# 4296                  8.0                        8.0                 6.0
#
#       amenities_length  availability_30  availability_60  availability_90  \
# 0                   11              0.0              0.0              0.0
# 1                   23             30.0             31.0             31.0
# 2                   11             10.0             10.0             21.0
# 3                   16             28.0             58.0             88.0
# 4                   13              0.0              0.0              0.0
# ...                ...              ...              ...              ...
# 5551                32              2.0             11.0             15.0
# 5552                 9              NaN              NaN              NaN
# 5553                15             28.0             54.0             82.0
# 5554                15              NaN              NaN              NaN
# 4296                13              0.0              5.0             35.0
#
#       availability_365  review_scores_accuracy  review_scores_cleanliness  \
# 0                 93.0                    10.0                        9.0
# 1                243.0                     9.0                       10.0
# 2                296.0                    10.0                        6.0
# 3                363.0                     0.0                        0.0
# 4                 32.0                     NaN                        NaN
# ...                ...                     ...                        ...
# 5551             154.0                     NaN                        NaN
# 5552               NaN                     NaN                        NaN
# 5553             351.0                     NaN                        NaN
# 5554               NaN                     NaN                        NaN
# 4296             190.0                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      10.0                         10.0
# 1                      10.0                          8.0
# 2                       8.0                          8.0
# 3                       0.0                          0.0
# 4                       NaN                          NaN
# ...                     ...                          ...
# 5551                    NaN                          NaN
# 5552                    NaN                          NaN
# 5553                    NaN                          NaN
# 5554                    NaN                          NaN
# 4296                    NaN                          NaN
#
#       review_scores_location  review_scores_value  review_scores_rating
# 0                       10.0                 10.0                  94.0
# 1                        9.0                  9.0                  88.0
# 2                        8.0                  8.0                  80.0
# 3                        0.0                  0.0                   0.0
# 4                        NaN                  NaN                   NaN
# ...                      ...                  ...                   ...
# 5551                     NaN                  NaN                   NaN
# 5552                     NaN                  NaN                   NaN
# 5553                     NaN                  NaN                   NaN
# 5554                     NaN                  NaN                   NaN
# 4296                     NaN                  NaN                   NaN
#
# [5555 rows x 51 columns]

# %%
airbnb_data10.isnull().sum()
# Out:
# name                              1
# property_type                     1
# room_type                         1
# bed_type                          1
# minimum_nights                    1
# maximum_nights                    1
# cancellation_policy               1
# accommodates                      1
# bedrooms                          1
# beds                              1
# number_of_reviews                 1
# bathrooms                         1
# price                             1
# extra_people                      1
# guests_included                   1
# street                            0
# suburb                            0
# government_area                   0
# market                            0
# country                           0
# country_code                      0
# type                              0
# Latitude                          0
# Longitude                         0
# is_location_exact                 0
# host_id                         459
# host_url                        459
# host_name                       459
# host_location                   459
# host_about                     2590
# host_thumbnail_urlt             459
# host_picture_url                459
# host_response_rate              459
# host_is_superhost               459
# host_has_profile_pic            459
# host_identity_verified          459
# host_listings_count             459
# host_total_listings_count       459
# host_verifications              459
# amenities_length                  0
# availability_30                2684
# availability_60                2684
# availability_90                2684
# availability_365               2684
# review_scores_accuracy         4391
# review_scores_cleanliness      4391
# review_scores_checkin          4391
# review_scores_communication    4391
# review_scores_location         4391
# review_scores_value            4391
# review_scores_rating           4391
# dtype: int64

# %%
airbnb_data10['host_location'].fillna(airbnb_data10['host_location'].mode(), inplace=True)

# %%
airbnb_data10['name'].fillna(airbnb_data10['name'].mode(), inplace=True)

# %%
airbnb_data10=airbnb_data10.drop(columns=['host_id','host_is_superhost','host_has_profile_pic','host_identity_verified'],axis=1)

# %%
airbnb_data10['host_response_rate'].fillna(airbnb_data10['host_response_rate'].mean(), inplace=True)
#'host_listings_count','host_total_listings_count','host_verifications'

# %%
airbnb_data10['host_listings_count'].fillna(airbnb_data10['host_listings_count'].mean(), inplace=True)
airbnb_data10['host_total_listings_count'].fillna(airbnb_data10['host_total_listings_count'].mean(), inplace=True)
airbnb_data10['host_verifications'].fillna(airbnb_data10['host_verifications'].mean(), inplace=True)

# %%
airbnb_data10.dropna(subset=['host_name','host_location'],inplace=True)
airbnb_data10.dropna(subset=['name'],inplace=True)

# %%
airbnb_data10['availability_365'].fillna(airbnb_data10['availability_365'].mean(), inplace=True)

# %%
airbnb_data10=airbnb_data10.drop(columns=['review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value'],axis=1)

# %%
airbnb_data10['review_scores_rating'].fillna(airbnb_data10['review_scores_rating'].mean(), inplace=True)

# %%
airbnb_data10['availability_30'].fillna(airbnb_data10['availability_30'].mean(), inplace=True)
airbnb_data10['availability_60'].fillna(airbnb_data10['availability_60'].mean(), inplace=True)
airbnb_data10['availability_90'].fillna(airbnb_data10['availability_90'].mean(), inplace=True)

# %%
airbnb_data10.isnull().sum()
# Out:
# name                            0
# property_type                   0
# room_type                       0
# bed_type                        0
# minimum_nights                  0
# maximum_nights                  0
# cancellation_policy             0
# accommodates                    0
# bedrooms                        0
# beds                            0
# number_of_reviews               0
# bathrooms                       0
# price                           0
# extra_people                    0
# guests_included                 0
# street                          0
# suburb                          0
# government_area                 0
# market                          0
# country                         0
# country_code                    0
# type                            0
# Latitude                        0
# Longitude                       0
# is_location_exact               0
# host_url                        0
# host_name                       0
# host_location                   0
# host_about                   2131
# host_thumbnail_urlt             0
# host_picture_url                0
# host_response_rate              0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# amenities_length                0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# review_scores_rating            0
# dtype: int64

# %%
airbnb_data1=airbnb_data10
airbnb_data1 #/content/sample_data
# Out:
#                                                   name property_type  \
# 0                  New York City - Upper West Side Apt     Apartment
# 1                                    Deluxe Loft Suite     Apartment
# 2                   Catete's Colonial Big Hause Room B         House
# 3                          Apt Linda Vista Lagoa - Rio     Apartment
# 4     Ligne verte - à 15 min de métro du centre ville.     Apartment
# ...                                                ...           ...
# 5099               OPO.APT -  Art Déco Apartment 110-1     Apartment
# 5100               3 bedroom + 2 bathroom apt near MTR   Condominium
# 5101                 [4] New BedRm by C.Park and 1,B,C     Apartment
# 5102                  Double bed room for 2 travellers     Apartment
# 5103                Long Island City- Furnished Studio     Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed             6.0           360.0
# 1     Entire home/apt  Real Bed             3.0          1125.0
# 2        Private room  Real Bed             2.0          1125.0
# 3        Private room  Real Bed             1.0          1125.0
# 4     Entire home/apt  Real Bed             2.0          1125.0
# ...               ...       ...             ...             ...
# 5099  Entire home/apt  Real Bed             3.0          1125.0
# 5100  Entire home/apt  Real Bed             1.0          1125.0
# 5101     Private room  Real Bed             1.0          1125.0
# 5102     Private room  Real Bed             6.0           365.0
# 5103  Entire home/apt  Real Bed             1.0          1125.0
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period           2.0       1.0   1.0
# 1     strict_14_with_grace_period           3.5       0.0   2.0
# 2     strict_14_with_grace_period           3.5       1.0   6.0
# 3                        flexible           2.0       1.0   1.0
# 4                        moderate           2.0       0.0   1.0
# ...                           ...           ...       ...   ...
# 5099  strict_14_with_grace_period           3.5       2.0   4.0
# 5100  strict_14_with_grace_period           3.5       3.0   4.0
# 5101  strict_14_with_grace_period           2.0       1.0   1.0
# 5102                     moderate           2.0       1.0   1.0
# 5103                     flexible           2.0       0.0   1.0
#
#       number_of_reviews  bathrooms   price  extra_people  guests_included  \
# 0                  70.0        1.0   135.0           0.0              1.0
# 1                   5.0        1.0   205.0           0.0              1.0
# 2                   1.0        1.0   250.0          40.0              4.0
# 3                   0.0        1.0   701.0           0.0              1.0
# 4                   0.0        1.0    43.0          12.0              1.0
# ...                 ...        ...     ...           ...              ...
# 5099              127.0        1.0    59.0           4.0              4.0
# 5100              106.0        1.0  1052.0         100.0              6.0
# 5101              175.0        1.0    95.0           0.0              1.0
# 5102               15.0        1.0   377.0         100.0              2.0
# 5103                9.0        1.0   110.0          25.0              2.0
#
#               street                 suburb                government_area  \
# 0           New York              Manhattan                Upper West Side
# 1           Brooklyn             Greenpoint                     Greenpoint
# 2     Rio de Janeiro                 Catete                         Catete
# 3     Rio de Janeiro                  Lagoa                          Lagoa
# 4           Montréal  Hochelaga-Maisonneuve  Mercier-Hochelaga-Maisonneuve
# ...              ...                    ...                            ...
# 5099           Porto                  Porto                      Cedofeita
# 5100       Hong Kong          Yau Tsim Mong                  Yau Tsim Mong
# 5101        New York        Upper West Side                Upper West Side
# 5102        Mong Kok               Mong Kok                  Yau Tsim Mong
# 5103          Queens                 Queens               Long Island City
#
#               market        country country_code   type   Latitude  \
# 0           New York  United States           US  Point  40.799620
# 1           New York  United States           US  Point  40.727780
# 2     Rio De Janeiro         Brazil           BR  Point -22.926382
# 3     Rio De Janeiro         Brazil           BR  Point -22.971951
# 4           Montreal         Canada           CA  Point  45.545480
# ...              ...            ...          ...    ...        ...
# 5099           Porto       Portugal           PT  Point  41.155040
# 5100       Hong Kong      Hong Kong           HK  Point  22.307200
# 5101        New York  United States           US  Point  40.798550
# 5102       Hong Kong      Hong Kong           HK  Point  22.318270
# 5103        New York  United States           US  Point  40.752260
#
#        Longitude  is_location_exact  \
# 0     -73.965230              False
# 1     -73.944720               True
# 2     -43.180157               True
# 3     -43.205047               True
# 4     -73.549490              False
# ...          ...                ...
# 5099   -8.623050               True
# 5100  114.165320               True
# 5101  -73.963890               True
# 5102  114.168530               True
# 5103  -73.940890               True
#
#                                         host_url host_name  \
# 0       https://www.airbnb.com/users/show/454250     Greta
# 1     https://www.airbnb.com/users/show/47554473       Mae
# 2     https://www.airbnb.com/users/show/51326285   Beatriz
# 3     https://www.airbnb.com/users/show/51496939     Livia
# 4      https://www.airbnb.com/users/show/7140229      Caro
# ...                                          ...       ...
# 5099   https://www.airbnb.com/users/show/1403065  Clarissa
# 5100  https://www.airbnb.com/users/show/40540485    Miguel
# 5101  https://www.airbnb.com/users/show/47615848      Lucy
# 5102   https://www.airbnb.com/users/show/2296185    Manuel
# 5103  https://www.airbnb.com/users/show/51303748      Eren
#
#                                         host_location  \
# 0                   New York, New York, United States
# 1                                                  US
# 2     Rio de Janeiro, State of Rio de Janeiro, Brazil
# 3                                                  BR
# 4                            Montreal, Quebec, Canada
# ...                                               ...
# 5099           Rio de Janeiro, Rio de Janeiro, Brazil
# 5100                New York, New York, United States
# 5101          Bondi Beach, New South Wales, Australia
# 5102                           Jovim, Porto, Portugal
# 5103                       Kadikoy, Çanakkale, Turkey
#
#                                              host_about  \
# 0     By now I have lived longer in the city than th...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5099  I am Brazilian, 39 y.o. live in Rio de Janeiro...
# 5100  We are a married couple who loves to travel ev...
# 5101                                                NaN
# 5102                                         From Porto
# 5103                                                NaN
#
#                                     host_thumbnail_urlt  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 3     https://a0.muscache.com/im/pictures/b7911710-9...
# 4     https://a0.muscache.com/im/pictures/user/c6477...
# ...                                                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5102  https://a0.muscache.com/im/users/2296185/profi...
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...
#
#                                        host_picture_url  host_response_rate  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...               100.0
# 1     https://a0.muscache.com/im/pictures/c680ce22-d...               100.0
# 2     https://a0.muscache.com/im/pictures/eb09c9cb-b...                80.0
# 3     https://a0.muscache.com/im/pictures/b7911710-9...                 0.0
# 4     https://a0.muscache.com/im/pictures/user/c6477...               100.0
# ...                                                 ...                 ...
# 5099  https://a0.muscache.com/im/pictures/8bd5fd4e-3...               100.0
# 5100  https://a0.muscache.com/im/pictures/f2065606-7...               100.0
# 5101  https://a0.muscache.com/im/pictures/b4675d0a-f...                 0.0
# 5102  https://a0.muscache.com/im/users/2296185/profi...                90.0
# 5103  https://a0.muscache.com/im/pictures/89a1b839-2...                 0.0
#
#       host_listings_count  host_total_listings_count  host_verifications  \
# 0                     3.0                        3.0                 6.0
# 1                    13.0                        8.5                 6.0
# 2                     5.0                        5.0                 6.0
# 3                     1.0                        1.0                 4.0
# 4                     1.0                        1.0                 5.0
# ...                   ...                        ...                 ...
# 5099                  2.0                        2.0                 4.0
# 5100                  1.0                        1.0                 5.0
# 5101                  1.0                        1.0                 2.0
# 5102                  3.0                        3.0                 6.0
# 5103                  2.0                        2.0                 2.0
#
#       amenities_length  availability_30  availability_60  availability_90  \
# 0                   11         0.000000         0.000000         0.000000
# 1                   23        30.000000        31.000000        31.000000
# 2                   11        10.000000        10.000000        21.000000
# 3                   16        28.000000        58.000000        88.000000
# 4                   13         0.000000         0.000000         0.000000
# ...                ...              ...              ...              ...
# 5099                20        10.000000        16.000000        24.000000
# 5100                12        11.000000        17.000000        33.000000
# 5101                22        12.000000        36.000000        60.000000
# 5102                 6         0.000000        12.000000        42.000000
# 5103                12        11.105461        26.381544        44.543126
#
#       availability_365  review_scores_rating
# 0            93.000000             94.000000
# 1           243.000000             88.000000
# 2           296.000000             80.000000
# 3           363.000000              0.000000
# 4            32.000000             86.048051
# ...                ...                   ...
# 5099        223.000000             86.048051
# 5100        290.000000             78.000000
# 5101        149.000000             86.048051
# 5102        317.000000             86.048051
# 5103        198.057627             86.048051
#
# [5095 rows x 41 columns]

# %%
airbnb_data = pd.DataFrame(airbnb_data1)

# %%
airbnb_data.to_csv('airbnb_data.csv', index=False)

# %%
airbnb_data.duplicated().sum()
# Out:
# 0
